# %% [markdown]
# # 정적 크롤링 : BeautifulSoup

# %% [markdown]
# ```
# uv add beautifulsoup4
# ```

# %% [markdown]
# * [참고자료, TCP School](https://tcpschool.com/html/html_intro_elementStructure)

# %% [markdown]
# # 1. 미니 실습

# %%
html = """
<html>
  <body>
    <div id="main" class="content">
      <h1>첫 번째 헤더</h1>
      <h1 class="header">두 번째 헤더</h1>
      <p class="description">설명입니다.</p>
      <a href="https://example1.com" class="link">링크 1</a>
      <a href="https://example2.com" class="link">링크 2</a>
      <a href="https://example3.com" class="external">링크 3</a>
    </div>
    <div id="main2" class="content">
      <div class="items">
        <div>
            <img class="thumbnail" src="/data/picture1.png" />
            <div class="title">타이틀1</div>
            <div class="description">설명1</div>
        </div>
        <div>
            <img class="thumbnail" src="/data/picture2.png" />
            <div class="title">타이틀2</div>
            <div class="description">설명2</div>
        </div>
        <div>
            <img class="thumbnail" src="/data/picture3.png" />
            <div class="title test">타이틀3</div>
            <div class="description">설명3</div>
        </div>
      </div>
    </div>
  </body>
</html>
"""

# %% [markdown]
# ## 1) HTML 파싱 준비

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Out:
# <html>
# <body>
# <div class="content" id="main">
# <h1>첫 번째 헤더</h1>
# <h1 class="header">두 번째 헤더</h1>
# <p class="description">설명입니다.</p>
# <a class="link" href="https://example1.com">링크 1</a>
# <a class="link" href="https://example2.com">링크 2</a>
# <a class="external" href="https://example3.com">링크 3</a>
# </div>
# <div class="content" id="main2">
# <div class="items">
# <div>
# <img class="thumbnail" src="/data/picture1.png"/>
# <div class="title">타이틀1</div>
# <div class="description">설명1</div>
# </div>
# <div>
# <img class="thumbnail" src="/data/picture2.png"/>
# <div class="title">타이틀2</div>
# <div class="description">설명2</div>
# </div>
# <div>
# <img class="thumbnail" src="/data/picture3.png"/>
# <div class="title test">타이틀3</div>
# <div class="description">설명3</div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# ## 2) 파싱

# %% [markdown]
# ###
# `
# soup.find('태그명', class_, id)
# `

# %%
# 맨 처음에 나오는 class 이름이 title인 div를 추출
soup.find("div", class_="title")
# Out:
# <div class="title">타이틀1</div>

# %%
soup.find("div", class_="title").text
# Out:
# '타이틀1'

# %% [markdown]
# ###
# `
# soup.find_all('태그명', class_, id)
# `

# %%
# class 이름이 title인 div를 모두추출
outputs = soup.find_all("div", class_="title")
outputs
# Out:
# [<div class="title">타이틀1</div>,
#  <div class="title">타이틀2</div>,
#  <div class="title test">타이틀3</div>]

# %%
for output in outputs :
    print(output.text)
# Out:
# 타이틀1
# 타이틀2
# 타이틀3

# %%
# "두 번째 헤더" 출력
# 목표 : <h1 class="header">두 번째 헤더</h1>
output = soup.find("h1", class_="header")
print(output.text)
# Out:
# 두 번째 헤더

# %%
# "설명3" 출력
outputs = soup.find_all("div", class_="description")
print(outputs[-1].text)
# Out:
# 설명3

# %%
# 태그 a를 모두 출력
outputs = soup.find_all("a")
print(outputs)
# Out:
# [<a class="link" href="https://example1.com">링크 1</a>, <a class="link" href="https://example2.com">링크 2</a>, <a class="external" href="https://example3.com">링크 3</a>]

# %% [markdown]
# ### 속성 추출

# %%
output = outputs[0]
print(output)
print(output.attrs)
print(output["href"])
print(output.attrs["href"])     # "href"라는 키가 없으면 오류
print(output.attrs.get("href")) # "href"라는 키가 없어도 오류가 안남
# Out:
# <a class="link" href="https://example1.com">링크 1</a>
# {'href': 'https://example1.com', 'class': ['link']}
# https://example1.com
# https://example1.com
# https://example1.com

# %%
# html에서 class 이름이 items 안에 있는 요소들로 데이터 프레임 만든다
# 열 이름은 image, title, description로 설정할 것이다
# image열에는 image의 scr 속성을,
# title열에는 class이름이 title인 요소의 텍스트,
# description열에는 class이름이 description열에는 요소의 텍스트

## 1. 태그가 div이고 class이름이 items인 데이터를 추출
items_html = soup.find("div", class_="items")
# print(items_html)

# %%
## 2. items_html에서 div인 것을 추출
### recursive = True
div_outputs = items_html.find_all("div")
for output in div_outputs :
    print(output)
    print("="*50)
# Out:
# <div>
# <img class="thumbnail" src="/data/picture1.png"/>
# <div class="title">타이틀1</div>
# <div class="description">설명1</div>
# </div>
# ==================================================
# <div class="title">타이틀1</div>
# ==================================================
# <div class="description">설명1</div>
# ==================================================
# <div>
# <img class="thumbnail" src="/data/picture2.png"/>
# <div class="title">타이틀2</div>
# <div class="description">설명2</div>
# </div>
# ==================================================
# <div class="title">타이틀2</div>
# ==================================================
# <div class="description">설명2</div>
# ==================================================
# <div>
# <img class="thumbnail" src="/data/picture3.png"/>
# <div class="title test">타이틀3</div>
# <div class="description">설명3</div>
# </div>
# ==================================================
# <div class="title test">타이틀3</div>
# ==================================================
# <div class="description">설명3</div>
# ==================================================

# %%
### recursive = False
div_outputs = items_html.find_all("div", recursive=False)
data_list = []
for output in div_outputs :
    temp_dict = {}
    temp_dict["image"] = output.find("img", class_="thumbnail").attrs.get("src")
    temp_dict["title"] = output.find("div", class_="title").text
    temp_dict["description"] = output.find("div", class_="description").text
    data_list.append(temp_dict)
    print(temp_dict)
# Out:
# {'image': '/data/picture1.png', 'title': '타이틀1', 'description': '설명1'}
# {'image': '/data/picture2.png', 'title': '타이틀2', 'description': '설명2'}
# {'image': '/data/picture3.png', 'title': '타이틀3', 'description': '설명3'}

# %%
data_list
# Out:
# [{'image': '/data/picture1.png', 'title': '타이틀1', 'description': '설명1'},
#  {'image': '/data/picture2.png', 'title': '타이틀2', 'description': '설명2'},
#  {'image': '/data/picture3.png', 'title': '타이틀3', 'description': '설명3'}]

# %%
import pandas as pd

data = pd.DataFrame(data_list)
data
# Out:
#                 image title description
# 0  /data/picture1.png  타이틀1         설명1
# 1  /data/picture2.png  타이틀2         설명2
# 2  /data/picture3.png  타이틀3         설명3

# %%
# 미션5: a 태그에서 href를 출력해주세요
## 목표: 맨 처음 나오는 a 태그를 추출 <a href="https://example1.com" class="link">링크 1</a>
print(soup.find("a").attrs)
print(soup.find("a").attrs["href"])
print(soup.find("a").get("href"))
print(soup.find("a")["href"])
# Out:
# {'href': 'https://example1.com', 'class': ['link']}
# https://example1.com
# https://example1.com
# https://example1.com

# %% [markdown]
# ### `soup.select_one("경로")`

# %%
# 링크 1 출력
soup.select_one('div > a')
# Out:
# <a class="link" href="https://example1.com">링크 1</a>

# %%
# 링크 2 출력 (div 안에 5번째 자식)
soup.select('div > a:nth-child(5)')
# Out:
# [<a class="link" href="https://example2.com">링크 2</a>]

# %% [markdown]
# ### `soup.select('경로')`

# %% [markdown]
# - 클래스명 : `태그명.클래스이름`
# - id명 : `#id이름`

# %%
# class가 items인 것 출력
soup.select('div.items')
# Out:
# [<div class="items">
#  <div>
#  <img class="thumbnail" src="/data/picture1.png"/>
#  <div class="title">타이틀1</div>
#  <div class="description">설명1</div>
#  </div>
#  <div>
#  <img class="thumbnail" src="/data/picture2.png"/>
#  <div class="title">타이틀2</div>
#  <div class="description">설명2</div>
#  </div>
#  <div>
#  <img class="thumbnail" src="/data/picture3.png"/>
#  <div class="title test">타이틀3</div>
#  <div class="description">설명3</div>
#  </div>
#  </div>]

# %%
# <div>
#     <img class="thumbnail" src="/data/picture3.png" />
#     <div class="title test">타이틀3</div>
#     <div class="description">설명3</div>
# </div>

# 이 요소만 출력
soup.select("div.items > div:nth-child(3)")
# Out:
# [<div>
#  <img class="thumbnail" src="/data/picture3.png"/>
#  <div class="title test">타이틀3</div>
#  <div class="description">설명3</div>
#  </div>]

# %% [markdown]
# # 2. 교보문고 크롤링

# %% [markdown]
# ## 1) HTML 요청하기

# %%
# https://search.kyobobook.co.kr/search?keyword=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&target=kyobo&gbCode=TOT&page=2

# %%
# import urllib 사용할때
base_url = "https://search.kyobobook.co.kr/search"
keyword = "%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5"
target = "kyobo"
gbCode = "TOT"
page = 1

url = f"{base_url}?keyword={keyword}&target={target}&gbCode={gbCode}&page={page}"

# %%
# request 이용

base_url = "https://search.kyobobook.co.kr/search"
keyword = "인공지능"
target = "kyobo"
gbCode = "TOT"
page = 1

params = {
    "keyword" : keyword,
    "target" : target,
    "gbCode" : gbCode,
    "page" : page
}

# User-Agent 입력 (개발자 도구에서 Network 들어간 후 복사해오기)
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

import requests
response = requests.get(base_url, params=params, headers=headers)
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko"
#     data-view="ink"
#     data-service="search"
# >
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#
#
#
#             <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1">
#
#
#
#
#
#         <meta name="title" content="인공지능 검색결과 | 교보문고">
#         <meta property="og:title" content="인공지능 검색결과 | 교보문고">
#
#
#
#         <meta name="description" content="꿈을 키우는 세상 교보문고는 온오프라인을 통틀어 대한민국 최고의 도서쇼핑몰이며 전자책, 음반, 기프트, 문화서비스까지 제공하는 종합문화기업입니다.">
#         <meta property="og:description" content="꿈을 키우는 세상 교보문고는 온오프라인을 통틀어 대한민국 최고의 도서쇼핑몰이며 전자책, 음반, 기프트, 문화서비스까지 제공하는 종합문화기업입니다.">
#
#
#     <meta property="og:type" content="website">
#     <meta property="og:image" content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo@2x.png">
#     <meta property="og:url" content="http://mobile.kyobobook.co.kr">
#
#
#
#
#
# <meta name="format-detection" content="date=no">
#
#
#
#
#
#
#
# <meta name="google-site-verification" content="2dlgBOp3K0s6wHjZo_Hkas6yaYPKZIVsmres9vC3F34">
#
# <meta name="google-site-verification" content="vN9Zag6odZ4sMyJfDMMSZTqbD-nbmnh0ituV4pk4FV4">
#
# <meta name="google-site-verification" content="AHqpy7PvqPoZwSySpolatuTj8M3B9F10Pi6UCldP5hE">
#
#
#
# <meta name="facebook-domain-verification" content="ezckujv1qppxlglsp8fsry2bs2cw0n">
#
#
#
# <meta name="naver-site-verification" content="bef3d190b10f8cada477f5531d206cc1a799c498">
#
#
#
#
#
#
#
#
#     <link rel="icon" type="image/png"
#           sizes="256x256"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_256x256.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="196x196"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_196x196.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="128x128"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_128x128.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="48x48"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_48x48.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="32x32"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_32x32.png">
#
#
#     <link rel="icon" type="image/png"
#           sizes="16x16"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_16x16.png">
#
#
#
#
#     <meta name="msapplication-TileImage" content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-144x144-precomposed.png">
#     <meta name="msapplication-TileColor" content="#222222">
#
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="700x700"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-700x700-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="180x180"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-180x180-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="167x167"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-167x167-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="152x152"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-152x152-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="144x144"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-144x144-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="120x120"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-120x120-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="114x114"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-114x114-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="80x80"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-80x80-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="72x72"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-72x72-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed apple-touch-icon"
#           sizes="60x60"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-60x60-precomposed.png">
#
#     <link rel="apple-touch-icon-precomposed"
#           href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-57x57-precomposed.png">
#
#
#
#
#
#
#
# <title>인공지능 검색결과 | 교보문고</title>
#
#
#
#
#
#
#
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@400;500;700&family=Roboto:wght@400;500;700&display=swap" />
#
#
#
#
#
#
#     <link rel="stylesheet" href="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery-ui.min.css" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <link rel="stylesheet" href="https://contents.kyobobook.co.kr/resources/vendors/swiper/v4/swiper.min.css" />
#
#
#
#
#
#     <link rel="stylesheet" href="https://contents.kyobobook.co.kr/resources/vendors/simplebar/5.3.3/simplebar.min.css" />
#
#
#
#
#
#
#
#     <link rel="stylesheet" href="https://contents.kyobobook.co.kr/resources/fo/css/loading.css" />
#
#
#
#
#
#     <link rel="stylesheet" type="text/css" href="https://contents.kyobobook.co.kr/resources/fo/css/style_ink.css?t=202507231211" data-name="kbb-cm-style" />
#
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/essential-vendors.min.js"></script>
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery-ui.min.js" data-name="jquery-ui"></script>
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery.ui.spinner.js"></script>
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/lottie-5.9.4/lottie.min.js"></script>
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-loading.js?t=202507231211"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/kbbjs-loader-v2.js?t=202507231211"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.js?t=202507231211" data-name="kbb.js"></script>
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.shared.js?t=202507231211" data-name="kbb.shared.js"></script>
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="/web/js/kyobo_search_auto.js?t=202507231211"></script>
#
#
#
#
#
#
# <script>
#     // IIFE
#     ;(function () {
#         // --------------------- [KbbJS/SSR] 서버 환경변수 전달
#         const CDN_URL = "https:\/\/contents.kyobobook.co.kr\/resources\/fo"
#
#         const tmpArr = CDN_URL.match(/((https?:)?\/\/[^/]+)(\/.*)/)
#         const cdnHost = tmpArr[1]
#         const cdnBaseURL = tmpArr[3]
#
#         KbbJS.setOption('service.cdn.host', cdnHost)
#         KbbJS.setOption('service.cdn.baseURL', cdnBaseURL)
#
#         /**
#          * KbbJS 라이브러리 경로 설정
#          */
#         let KbbjsURL = "\/lib\/kbb-js"
#         if (!/^(https?:|\/\/)/.test(KbbjsURL)) {
#             KbbjsURL = CDN_URL + KbbjsURL
#         }
#
#         const KBBJS_VER = "v2.0\/latest"
#         if (KBBJS_VER != null) {
#             KbbjsURL += '/' + KBBJS_VER
#         } else {
#             KbbjsURL = "https:\/\/search.kyobobook.co.kr\/lib\/kbb-js"
#         }
#
#         // KbbJS 배포 개선 작업 1차 - 속성 추가
#         KbbJS.setOption('loader.bootstamp', "202507231211")
#         KbbJS.setOption('loader.baseURL', KbbjsURL)
#
#         // 인증여부 속성 추가
#         KbbJS.setOption('loader.authorized', false)
#         KbbJS.setOption('loader.user.nickname', null)
#         KbbJS.setOption('loader.user.picture', null)
#
#         // 디바이스 정보 설정
#         KbbJS.setOption('ua.device', {
#             isMobile: false,
#             isMobileApp: false,
#             isIOS: false,
#             isAndroid: false,
#             isMSIE: false,
#             isMac: false
#         })
#
#         /**
#          * 서비스 호스트 설정
#          */
#         const oServiceData = {"hosts":{"ebook-product":"https:\/\/ebook-product.kyobobook.co.kr","semo":"https:\/\/semo.kyobobook.co.kr","product":"https:\/\/product.kyobobook.co.kr","ecash":"https:\/\/ecash.kyobobook.co.kr","elibrary":"https:\/\/elibrary.kyobobook.co.kr","best":"https:\/\/best.kyobobook.co.kr","bookcast":"https:\/\/casting.kyobobook.co.kr","store":null,"undefined":null,"search":"https:\/\/search.kyobobook.co.kr","ebook":"https:\/\/ebook.kyobobook.co.kr","member":"https:\/\/mmbr.kyobobook.co.kr","myroom":"https:\/\/my.kyobobook.co.kr","event":"https:\/\/event.kyobobook.co.kr","welcome":"https:\/\/www.kyobobook.co.kr","hottracks":"https:\/\/hottracks.kyobobook.co.kr\/","sam":"https:\/\/sam.kyobobook.co.kr","order":"https:\/\/order.kyobobook.co.kr"}}
#         const oServiceHosts = _.get(oServiceData, 'hosts', {})
#         _.forEach(_.keys(oServiceHosts), function (key) {
#             let prop = key
#             switch (key.toLowerCase()) {
#                 case 'ebookproduct':
#                 case 'ebook-product':
#                     prop = 'ebookProduct';
#                     break
#                 case 'elibrary':
#                     prop = 'eLibrary'
#                     break
#             }
#             let value = _.get(oServiceHosts, key)
#             if (value == null) {
#                 // 기본 호스트 설정
#                 switch (key.toLowerCase()) {
#                     case 'welcome': value = 'www'; break
#                     case 'myroom': value = 'my'; break
#                     case 'bookcast': value = 'casting'; break
#                     case 'member': value = 'mmbr'; break
#                     case 'ebookproduct':
#                     case 'ebook-product':
#                         value = 'ebook-product'
#                         break
#                     case 'elibrary':
#                         value = 'elibrary'
#                         break
#                     case 'product':
#                     case 'event':
#                     case 'order':
#                     case 'search':
#                     case 'best':
#                     case 'ebook':
#                     case 'sam':
#                     case 'store':
#                     case 'ecash':
#                         value = prop
#                         break
#                 }
#                 if (value == null) return
#                 value = 'https://' + value + '.kyobobook.co.kr'
#             }
#             KbbJS.setOption('service.' + prop + '.host', value)
#         })
#     }())
# </script>
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-netfunnel.js?t=202507231211"></script>
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/common-vars.js?t=202507231211"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/vars/common.js?t=202507231211" data-name="vars.common"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/vars/paper.js?t=202507231211" data-name="vars.service"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.stats.js?t=202507231211" data-name="kbb.stats.js"></script>
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.gautil.js?t=202507231211" data-name="kbb.gautil.js"></script>
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/common-vars.js?t=202507231211"></script>
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/util.js?t=202507231211"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="/web/js/kyobo_search_common.js?t=202507231211"></script>
#
#
#
#
#         <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-cubot-loader.js?t=1753323209882" defer></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/vendors.min.js?t=202507231211" data-name="kbb-vendors.min.js"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/shared.min.js?t=202507231211" data-name="kbb-shared.min.js"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/components.min.js?t=202507231211" data-name="kbb-components.min.js"></script>
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/core.min.js?t=202507231211" data-name="kbb-core.min.js"></script>
#
#
#
#
#
#
#
#
#
#
# </head>
# <body>
#
#         <div id="KbbLoading"
#     class="loading_box show"
# >
#     <div class="loading_box_inner">
#         <div class="loading_target"></div>
#     </div>
#     <div class="loading_dimmed"></div>
# </div>
#
#
#
#
#
#
#
#
#
#             <div class="skip_nav_wrap">
#                 <a href="#contents">본문 바로가기</a>
#             </div>
#             <div class="wrapper contents_search_result" id="mainDiv">
#
#
#
#
#             <!--
#             - 2024.02.05 PC인 경우 통합 GNB로 변경
#             - #TODO 모바일 통합 GNB 적용
#             -->
#
#
#     <header class="header_wrapper has_banner header_v2 united_header mall_book sps" id="welcome_header_wrap">
#
#     <!--
#     <th:block th:if="${(alCode=='EET'||alCode=='EMT'||alCode=='EHT'||alCode=='EAT') and alBannerGbn!='true'}">
#         <div class="top_banner_wrap" id="welcome_top_banner">
#             <div class="top_banner_inner">
#                 <a href="https://event.kyobobook.co.kr/detail/206105"><img class="img_top_banner" src="https://contents.kyobobook.co.kr/pmtn/2023/book/230104_ebs/bn/bnM_02.png" alt="EBS X 교보문고 고객님을 위한 5천원 열공 혜책!"></a>
#                 <button type="button" class="btn_close_banner">배너 닫기</button>
#             </div>
#         </div>
#     </th:block>
#     -->
#     <div class="service_mall_wrap">
#  <div class="service_mall_inner">
#   <div class="service_mall_box">
#    <ul class="service_mall_list">
#     <li class="service_mall_item tab book"><a class="service_mall_link" href="https://www.kyobobook.co.kr/">교보문고</a></li>
#     <li class="service_mall_item tab ebook"><a class="service_mall_link" href="https://ebook.kyobobook.co.kr/">eBook</a></li>
#     <li class="service_mall_item tab sam"><a class="service_mall_link" href="https://sam.kyobobook.co.kr/">sam</a></li>
#     <li class="service_mall_item tab hottracks"><a class="service_mall_link" href="https://hottracks.kyobobook.co.kr/ht/welcomeMain">핫트랙스</a></li>
#     <li class="service_mall_item tab link"><a target="_blank" class="service_mall_link" href="https://storynew.kyobobook.co.kr/story/main/initMain.ink">스토리</a></li>
#     <li class="service_mall_item brand_more"><button type="button" class="btn_brand_more"><span class="text">브랜드 더보기</span></button>
#      <div class="brand_more_list_box">
#       <div class="custom_scroll_wrap">
#        <ul class="brand_more_list">
#         <li class="brand_more_item"><a class="brand_more_link" href="https://product.kyobobook.co.kr/pod/main"><span class="img_box"><img loading="lazy" alt="바로출판 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_pod@2x.png"></span><span class="brand_name">바로출판</span></a></li>
#         <li class="brand_more_item"><a target="_blank" class="brand_more_link" href="https://readlog.kyobobook.co.kr/intro"><span class="img_box"><img loading="lazy" alt="리드로그 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_readlog@2x.png"></span><span class="brand_name">리드로그</span></a></li>
#        </ul>
#       </div>
#      </div></li>
#    </ul>
#   </div>
#   <div class="customer_service_box">
#    <ul class="customer_service_list">
#     <li class="customer_service_item" style="display:none"><a class="util_link" href="https://mmbr.kyobobook.co.kr/join">회원가입</a></li>
#     <li class="customer_service_item" style="display:none"><a class="util_link" href="https://mmbr.kyobobook.co.kr/login">로그인</a></li>
#     <li class="customer_service_item member_benefit"><button type="button" class="btn_member_benefit"><span class="text">회원혜택</span></button>
#      <ul class="member_benefit_list">
#       <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit">교보북클럽</a></li>
#       <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/grade">등급 혜택</a></li>
#       <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/new">신규회원 혜택</a></li>
#       <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/prestige">Prestige Lounge</a></li>
#       <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/discount">제휴 혜택</a></li>
#      </ul></li>
#     <li class="customer_service_item order"><a class="util_link" href="https://order.kyobobook.co.kr/myroom/member/order-list">주문배송</a></li>
#     <li class="customer_service_item store"><a class="util_link" href="https://store.kyobobook.co.kr/store-info/001">매장안내</a></li>
#     <li class="customer_service_item"><a class="util_link" href="https://www.kyobobook.co.kr/cscenter">고객센터</a></li>
#    </ul>
#   </div>
#  </div>
# </div>
# <div class="header_inner">
#  <div class="gnb_search_wrap">
#   <div class="logo_box"> <a class="logo_link book" href="https://www.kyobobook.co.kr/"><span class="hidden">교보문고</span></a>
#   </div>
#   <div class="gnb_search_box">
#    <div class="form_sel" data-class="type_gnb"> <select title="검색유형선택" id="gbCode"><option value="TOT">통합검색</option><option value="KBO">교보문고</option><option value="EBK">eBook</option><option value="SAM">sam</option><option value="HTS">핫트랙스</option></select>
#    </div>
#    <div class="search_input_wrap">
#     <input id="searchKeyword" type="search" class="ip_gnb_search" title="통합검색어 입력" autocomplete="off" placeholder="검색어를 입력해주세요." value="">
#     <input type="hidden" id="searchBoxEventurl" name="searchBoxEventurl" value="">
#     <script>jQuery(function () {
#     jQuery.getJSON('/api/adv?url=/INK/ink_wel_new/ink_wel@wel_02?callback=', function (data) {
#         var search_placeholder_txt = document.createElement('textarea');
#         search_placeholder_txt.innerHTML = data[0].text;
#         $(".ip_gnb_search").attr("placeholder", search_placeholder_txt.value);
#         $('#searchBoxEventurl').val(data[0].linkUrl);
#
#         setGtmForPlaceholder(data);
#     });
#   });</script><button type="button" class="btn_ip_clear"><span class="hidden">초기화</span></button>
#    </div><a data-role="gnb-search-submit" class="btn_gnb_search" href="javascript:goAutoSearchLayer()"><span class="hidden">검색</span></a>
#   </div>
#   <ul class="user_menu_list">
#    <li class="user_menu_item cash"><a class="user_menu_link" title="e캐시" href="https://ecash.kyobobook.co.kr/dig/opr/ecash/general"><span class="hidden">e캐시</span></a></li>
#    <li class="user_menu_item library"><a class="user_menu_link" title="내서재" href="https://elibrary.kyobobook.co.kr/dig/elb/elibrary"><span class="hidden">내서재</span></a></li>
#    <li class="user_menu_item cart"><a class="user_menu_link" title="장바구니" href="https://order.kyobobook.co.kr/cart"><span class="hidden">장바구니</span><span data-kbbfn="cart-size" style="display:none" class="cnt"></span></a></li>
#    <li class="user_menu_item my"><a data-render="ssr" class="profile-icon user_menu_link done" title="프로필" href="https://my.kyobobook.co.kr/main"><span class="img_box no_img"><img alt="로그인"></span><span class="hidden">프로필</span></a><script src="https://contents.kyobobook.co.kr/resources/fo/js/user-profile.js"></script></li>
#   </ul>
#   <div class="auto_complete_wrap auto_complete_maintain" id="hFrame">
#    <div class="search_content_wrap inKeyword">
#     <div class="scroll_wrap"></div>
#    </div>
#    <div class="search_content_wrap noKeyword">
#     <div class="scroll_wrap">
#      <div class="recommend_keyword_area">
#       <div class="title_wrap title_size_def">
#        <p class="title_heading">추천 검색어</p>
#       </div>
#       <div class="tag_wrap" id="recommendKeywordBox"></div>
#      </div>
#      <div class="keyword_contents_area">
#       <div class="recent_keyword_box"></div>
#       <div class="keyword_prod_box" id="keyWordProdBox"></div>
#       <div class="hot_keyword_box" id="hotKeywordBox">
#        <div class="title_wrap title_size_def">
#         <p class="title_heading">실시간 인기 검색어</p>
#         <div class="right_area"></div>
#        </div>
#        <div class="hot_keyword_list_wrap"></div>
#       </div>
#      </div>
#     </div>
#     <div class="util_area">
#      <div class="util_button_area"> <a href="javascript:goCsCenter();" class="btn_xs"><span class="ico_link"></span><span class="text">도움말</span></a><a href="javascript:goDetailSearch();" class="btn_xs"><span class="ico_search"></span><span class="text">상세검색</span></a>
#      </div><button type="button" class="button_layer_close" id="close_search_auto"><span class="text">닫기</span></button>
#     </div>
#    </div>
#   </div>
#  </div>
#  <nav class="gnb_wrap">
#   <div class="anb_wrap"> <button type="button" class="btn_anb"><span class="hidden">전체메뉴</span></button>
#    <div class="anb_area">
#     <div class="tab_wrap">
#      <div class="tab_list_wrap">
#       <ul class="tabs">
#        <li class="tab_item"><a href="#tabAnbCategory" class="tab_link"><span class="tab_text">카테고리 전체보기</span></a></li>
#        <li class="tab_item"><a href="#tabAnbService" class="tab_link"><span class="tab_text">서비스 전체보기</span></a></li>
#       </ul>
#      </div>
#      <div id="tabAnbCategory" class="tab_content">
#       <div class="tab_wrap type_md channel">
#        <div class="tab_list_wrap">
#         <ul class="tabs">
#          <li class="tab_item ui-tabs-active ui-state-active"><a href="#tabAnbCategoryKyobo" class="tab_link"><span class="tab_text">교보문고</span></a></li>
#          <li class="tab_item"><a href="#tabAnbCategoryEbook" class="tab_link"><span class="tab_text">eBook</span></a></li>
#          <li class="tab_item"><a href="#tabAnbCategorySam" class="tab_link"><span class="tab_text">sam</span></a></li>
#          <li class="tab_item"><a href="#tabAnbCategoryHotTracks" class="tab_link"><span class="tab_text">핫트랙스</span></a></li>
#         </ul>
#        </div>
#        <div id="tabAnbCategoryKyobo" class="tab_content anb_category">
#         <div class="anb_category_inner">
#          <div class="tab_wrap category">
#           <div class="tab_list_wrap">
#            <ul class="tabs">
#             <li class="tab_item"><a href="#tabAnbCategorySub00" class="tab_link"><span class="tab_text">국내도서</span></a></li>
#             <li class="tab_item"><a href="#tabAnbCategorySub01" class="tab_link"><span class="tab_text">서양도서</span></a></li>
#             <li class="tab_item"><a href="#tabAnbCategorySub02" class="tab_link"><span class="tab_text">일본도서</span></a></li>
#             <li class="tab_item"><a href="#tabAnbCategorySub03" class="tab_link"><span class="tab_text">교보Only</span></a></li>
#            </ul>
#           </div>
#           <div id="tabAnbCategorySub00" class="tab_content has_banner">
#            <div class="custom_scroll_wrap">
#             <div class="category_view_area"> <a target="_self" class="btn_arw_link" href="https://product.kyobobook.co.kr/"><span class="text">국내도서 전체</span></a>
#              <div class="fold_box_wrap category">
#               <div class="col_area">
#                <ul class="fold_box_list">
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/01">소설</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0101">한국소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0103">영미소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0105">일본소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0107">중국소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0109">러시아소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0111">프랑스소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0112">독일소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0115">북유럽소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0116">그외유럽소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0117">기타나라소설</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0121">고전소설/문학선</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0124">세계문학전집</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0126">라이트노벨</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0128">장르소설</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/03">시/에세이</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0301">한국시</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0302">해외시</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0304">테마에세이</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0307">나라별 에세이</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0311">인물/자전적에세이</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0317">청소년 시/에세이</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0319">시/에세이문고</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/05">인문</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0501">인문학일반</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0503">심리학</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0505">교육학</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0507">유아교육</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0509">특수교육</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0511">임용고시</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0513">철학</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0515">문학이론</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0517">한국문학론</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0519">영미문학론</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0520">중국문학론</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0521">세계문학론</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0523">언어학</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0525">독서/글쓰기</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0527">문헌정보학</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0529">역학/사주</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0532">대학교재</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0533">인문교양총서</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0535">인문고전총서</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0551">방송통신대교재</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/07">가정/육아</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0701">결혼/가정</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0703">임신/출산</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0704">육아</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0705">자녀교육</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0707">살림의지혜</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0709">홈인테리어</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/08">요리</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0801">요리일반</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0802">요리에세이</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0803">테마별요리</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0805">베이킹/간식</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0807">계절요리</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0809">재료별요리</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0811">나라별요리</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0813">생활요리</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0815">전문요리</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0817">와인/커피/음료</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0819">요리수험서</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/09">건강</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0901">건강일반</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0903">뇌건강</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0905">한방치료</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0907">자연건강</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0908">건강식사</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0909">질병치료/예방</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0911">다이어트</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0913">운동/트레이닝</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0915">피부관리/메이크업</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0920">건강문고</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/11">취미/실용/스포츠</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1101">가정원예</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1102">홈인테리어/수납</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1103">생활공예/DIY</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1104">살림의지혜</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1105">반려동물</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1107">등산/낚시</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1109">바둑/골프</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1113">무술</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1115">스포츠</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1117">레크레이션/게임</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1118">퀴즈/퍼즐/스도쿠</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1119">무용</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1121">체육</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1124">취미일반</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1125">취미관련상품</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1130">대학교재</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/13">경제/경영</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1301">경영일반</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1303">경영이론</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1305">경영관리</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1307">경영전략</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1309">경제일반</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1311">경제이론</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1313">경제실무</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1315">각국경제</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1316">세무/회계</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1319">마케팅/광고/고객</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1321">유통/창업</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1323">재테크/금융</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1325">무역/운송</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1327">관광/호텔</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1329">경제/경영문고</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1331">대학교재</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/15">자기계발</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1501">성공/처세</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1503">자기능력계발</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1505">비즈니스능력계발</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1506">인간관계</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1507">화술/협상</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1508">청소년자기계발</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1509">오디오북</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1519">전자책단말기/전자기기</a></li>
#                   </ul>
#                  </div></li>
#                 <li class="fold_box ">
#                  <div class="fold_box_header"> <a target="_self" class="" href="https://product.kyobobook.co.kr/category/KOR/17">정치/사회</a><button type="button" class="btn_fold"><span class="hidden">컨텐츠 열기</span></button>
#                  </div>
#                  <div class="fold_box_contents">
#                   <ul class="category_list">
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1701">정치/외교</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1703">행정/정책</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1705">국방/군사</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1707">법학</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1709">사회학</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1711">사회문제/복지</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1713">언론/신문/방송</a></li>
#                    <li class="category_item"><a target="_self" class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1715">정치/사회문고</a></li>
# ...
#     $("#evtDtlBtn").on("click", function(e){
#         location.href = eventUrl;
#     });
#     $("#ebsEventNextBtn").on("click", function(e){
#         setSearchCookie("ALLIENCE_BANNER","true",new Date(Date.now() + (1000*60*60*24)),'/','.kyobobook.co.kr');
#         $("#popBurst").dialog("close");
#     });
# </script>
#
#
#                         </div>
#                         <!-- //tab_content -->
#                     </div>
#                     <!-- //tab_wrap -->
#                 </div>
#             </div>
#         </section>
#         <!-- // contents_wrap -->
#     </main>
#
#
#
# <!-- 윙배너 -->
# <section class="fly_menu_wrapper sps" id="fly_wing_banner">
#     <div class="fly_menu_inner">
#         <a href="javascript:void(0)" class="fly_menu_banner" onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '배너', '');"><img></a>
#
#         <div class="fly_event_area">
#             <a href="javascript:void(0)" class="fly_menu_link" onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '이벤트', '');">이벤트</a>
#             <div class="fly_event_banner">
#                 <div class="swiper-container">
#                     <ul class="swiper-wrapper">
#
#                     </ul>
#                 </div>
#                 <div class="swiper_control_box">
#                     <button type="button" class="swiper-button-prev"><span class="hidden">이전</span></button>
#                     <div class="swiper-pagination"></div>
#                     <button type="button" class="swiper-button-next"><span class="hidden">다음</span></button>
#                 </div>
#             </div>
#         </div>
#
#         <div class="fly_link_box">
#             <a id="wing_coupon" href="javascript:void(0)" class="fly_menu_link" onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '쿠폰/혜택', '');">쿠폰/혜택</a>
#         </div>
#     </div>
# </section>
# <!-- // 윙배너 -->
#
#
#         <div id="floating_wrapper" class="floating_wrapper">
#
#
#
#
#
#             <div id="recent-contents" onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '최근본상품', '');"></div>
#
#
#
#
#
#
#
#
#
#
#     <a href="#top" class="btn_go_top" title="최상위 화면으로">
#
#     <span onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '맨위로', '');">TOP</span>
#
#
# </a>
#
#
#
#
#
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
# <footer class="footer_wrapper"
#         data-kbbfn="ui-module"
#         data-kbbfn-name="footer-notice"
# >
#
#     <div class="footer_header default">
#
#     <div class="footer_inner">
#         <div class="notice_wrap">
#             <span class="notice_text">공지사항</span>
#         </div>
#         <div class="notice_wrap winner">
#             <span class="notice_text">당첨자발표</span>
#         </div>
#     </div>
# </div>
#
#     <div class="footer_body">
#     <div class="footer_inner">
#     <div class="logo_box">
#
#
#     <!-- <th:block th:insert="common/fragments/onk/logo :: main(logoPosition='footer')" /> -->
#     <div class="logo_box">
#     <a href="https://www.kyobobook.co.kr/" class="logo_link book"
#     >
#
#
#
#
#         <img alt="KYOBO 교보문고" srcset="
#             https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo_footer.png 1x,
#             https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo_footer@1.5x.png 1.5x,
#             https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo_footer@2x.png 2x"
#         />
#
# </a>
#
#
# </div>
#
#         <div class="right_box">
#
#             <div class="family_site_box">
#
#
#         <button type="button" class="btn_family_site"><span class="text">Family Site</span></button>
#         <ul class="family_site_list">
#
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kyobo.com">교보생명</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.iprovest.com">교보증권</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kyobodts.co.kr">교보DTS</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kyoborealco.co.kr">교보리얼코</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kyoboaxa-im.co.kr">교보악사자산운용</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.lifeplanet.co.kr">교보라이프플래닛생명</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kcasonsa.co.kr">KCA 손해사정</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kcase.co.kr">KCA 서비스</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kyobotrust.co.kr">교보자산신탁주식회사</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="http://kyobo-aim.com/">교보AIM자산운용</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kyobodasomcare.com">교보다솜케어</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.andamc.com">A&amp;D신용정보</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.daesan.or.kr">대산문화재단</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.kbedu.or.kr">교보교육재단</a>
#     </li>
#     <li class="family_site_item">
#
#         <a class="family_site_link" target="_blank" href="https://www.dsa.or.kr">대산농촌재단</a>
#     </li>
#
#         </ul>
#
# </div>
#
#
# <div class="sns_share_box">
#
#         <a class="btn_sns_share youtube" target="_blank"
#            href="https://www.youtube.com/c/kbooknews"
#         ><span class="hidden">youtube 공유</span></a>
#
#         <a class="btn_sns_share fb" target="_blank"
#            href="https://www.facebook.com/kyobobookonline?orderClick=rwk"
#         ><span class="hidden">facebook 공유</span></a>
#
#         <a class="btn_sns_share insta" target="_blank"
#            href="https://www.instagram.com/kyobobook_online/"
#         ><span class="hidden">instagram 공유</span></a>
#
# </div>
#
#         </div>
#     </div>
#     <div class="footer_contents_wrap">
#         <div class="footer_contents_left">
#
#             <div class="footer_menu_box">
#
#     <ul class="footer_menu_list">
#
#
#             <li class="footer_menu_item"
#             >
#
#                 <a class="footer_menu_link"
#                    target="_blank"
#                    href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=intro"
#                 >회사소개</a>
#             </li>
#
#
#
#             <li class="footer_menu_item"
#             >
#
#                 <a class="footer_menu_link"
#                    href="https://www.kyobobook.co.kr/contents/provision"
#                 >이용약관</a>
#             </li>
#
#
#
#             <li class="footer_menu_item privacy"
#             >
#
#                 <a class="footer_menu_link"
#                    href="https://www.kyobobook.co.kr/contents/privacy-policy"
#                 >개인정보처리방침</a>
#             </li>
#
#
#
#             <li class="footer_menu_item"
#             >
#
#                 <a class="footer_menu_link"
#                    href="https://www.kyobobook.co.kr/contents/youth-policy"
#                 >청소년보호정책</a>
#             </li>
#
#
#
#             <li class="footer_menu_item"
#             >
#
#                 <a class="footer_menu_link"
#                    href="https://big.kyobobook.co.kr"
#                 >대량주문안내</a>
#             </li>
#
#
#
#             <li class="footer_menu_item"
#             >
#
#                 <a class="footer_menu_link"
#                    href="https://www.kyobobook.co.kr/partners/chargeperson"
#                 >협력사여러분</a>
#             </li>
#
#
#
#             <li class="footer_menu_item"
#             >
#
#                 <a class="footer_menu_link"
#                    target="_blank"
#                    href="https://ehr.kyobobook.co.kr/recr/recruit_system_1.jsp"
#                 >채용정보</a>
#             </li>
#
#
#
#             <li class="footer_menu_item"
#             >
#
#                 <a class="footer_menu_link"
#                    target="_blank"
#                    href="https://ad.kyobobook.co.kr"
#                 >광고소개</a>
#             </li>
#
#
#     </ul>
#
# </div>
#
#             <address class="footer_info_box">
#
#
#     <span class="info_text">대표이사 : 허정도</span>
#     <span class="gap">|</span>
#     <span class="info_text">서울특별시 종로구 종로 1</span>
#     <span class="gap">|</span>
#
#     <span class="info_text">사업자등록번호 : 102-81-11670</span> <br/>
#     <span class="info_text call">대표전화 : 1544-1900(발신자 부담전화)</span>
#
#     <span class="gap">|</span>
#     <span class="info_text">FAX : 0502-987-5711(지역번호 공통)</span>
#     <span class="gap">|</span>
#     <span class="info_text">서울특별시 통신판매업신고번호 : 제 653호</span>
#
#
#     <a href="http://www.ftc.go.kr/info/bizinfo/communicationViewPopup.jsp?wrkr_no=1028111670" class="btn_footer_link"
#        target="_blank">사업자정보확인</a>
#
#
#
# </address>
#             <div class="copyright">
#
#     <span>© KYOBO BOOK CENTRE</span>
# </div>
#         </div>
#         <div class="footer_contents_right">
#             <div class="footer_service">
#                 <span class="service_text">토스페이먼츠 구매안전서비스 </span>
#                 <a href="https://pgweb.tosspayments.com/ms/escrow/s_escrowYn.do?mertid=ink0911" class="btn_footer_link"
#                    target="_blank">서비스 가입 확인</a>
#                 <p class="service_desc">
#                     고객님은 안전거래를 위해 현금 등으로 결제시 저희 쇼핑몰에서 가입한 <br/>
#                     토스페이먼츠의 구매안전서비스를 이용하실 수 있습니다.
#                 </p>
#             </div>
#             <div class="footer_mark_isms">
#     <a target="_blank" href="https://www.kyobobook.co.kr/pop_isms" class="mark_link">
#         정보보호관리체계<br />
#         ISMS 인증획득
#     </a>
#
#     <p class="mark_desc">
#         [인증범위] 인터넷 교보문고 및 브랜드 서비스 운영<br />
#         [유효기간] 2023.11.15 ~ 2026.11.14
#     </p>
# </div>
#
#         </div>
#     </div>
# </div>
# </div>
# </footer>
#
#
#             </div>
#
#
#
#
#
#
#
#
#
#         <!-- LayerPopup area -->
#
# <!-- 스펙비교 레이어 팝업 -->
# <div class="spec_compare_layer_wrap">
#     <div class="compare_layer_inner">
#         <button type="button" class="btn_layer_close" onclick="closeSpecPopup()"><span class="ico_layer_close"></span><span class="hidden">닫기</span></button>
#         <div class="compare_title_area">
#             <div class="title_wrap title_size_md has_sub_title">
#                 <p class="title_heading">스펙비교</p>
#                 <p class="info_text">비교상품을 추가해보세요.</p>
#             </div>
#             <div class="compare_btn_box">
#                 <button type="button" class="btn_ip btn_line_gray" onclick="deleteAllSpecProd()"><span class="ico_delete"></span><span class="text">전체삭제</span></button>
#                 <a href="javascript:goSpecComparePage();" class="btn_ip btn_primary"><span class="text">스펙비교</span></a>
#             </div>
#         </div>
#         <div class="compare_prod_area">
#             <ul class="compare_prod_list" id="spec_compare_list">
#             </ul>
#         </div>
#     </div>
# </div>
# <!-- //스펙비교 레이어 팝업 -->
#
# <!-- // LayerPopup area -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/react-bundle.min.js" data-name="react-bundle"></script>
#
#
#
# <!-- NetFUNNEL 스크립트 -->
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/netfunnel/custom-netfunnel.js" data-name="netfunnel"></script>
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/css-element-queries/ResizeSensor.js" data-name="ResizeSensor"></script>
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/awesomplete/awesomplete.min.js" data-name="awesomplete"></script>
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.recent.js?t=202507231211" data-name="kbb.recent.js"></script>
#
#
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/scrollpos-styler/scrollPosStyler.min.js" data-name="scrollPosStyler"></script>
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/blurify-master/blurify.min.js" data-name="blurify"></script>
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/masonry/masonry.pkgd.min.js" data-name="masonry"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/swiper/v4/swiper.min.js" data-name="swiper"></script>
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/svgxuse/svgxuse.js" data-name="svgxuse"></script>
#
#
#
#
#
#
#     <script src="https://contents.kyobobook.co.kr/resources/vendors/simplebar/5.3.3/simplebar.min.js" data-name="simplebar"></script>
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="https://contents.kyobobook.co.kr/resources/fo/js/ui_ink.js?t=202507231211" data-name="kbb-cm-script"></script>
#
#
#
#
#
#
#
#
#     <script type="text/javascript" src="/assets/js/vars.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/common/js/kyobo_search_review.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/web/js/kyobo_search_filter.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/web/js/kyobo_search_spec.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/common/js/kyobo_search_gtm.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/common/js/kyobo_search_click_event.js?t=202507231211"></script>
#
#
#
#
#
#
#     <script type="text/javascript" src="/common/js/kyobo_search_lazy.js?t=202507231211"></script>
#
#
#
#
#
#
#         <!-- /* 큐봇(cubot) 스크립트 삽입 */-->
#
#     <script>
#         const maxAttempts = 12;
#         const attemptInterval = 5000; // 5초
#
#         function initializeCuBotWidgetAsync(page) {
#             return new Promise((resolve, reject) => {
#                 let attempts = 0;
#
#                 function tryInitialize() {
#                     if (window.initializeCubotWidget) {
#                         window.initializeCubotWidget({page: page});
#                         resolve();
#                     } else if (attempts < maxAttempts) {
#                         setTimeout(tryInitialize, attemptInterval);
#                         attempts++;
#                     } else {
#                         reject();
#                     }
#                 }
#
#                 tryInitialize();
#             });
#         }
#
#         document.addEventListener('DOMContentLoaded', () => {
#             initializeCuBotWidgetAsync("search")
#                 .then(() => console.log('CuBot Widget initialized successfully'));
#         });
#     </script>
#
#
#
#
#
# </body>
# </html>

# %% [markdown]
# ## 2) HTML 파싱 준비

# %%
from bs4 import BeautifulSoup

html = response.text
soup = BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# <html data-service="search" data-view="ink" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="인공지능 검색결과 | 교보문고" name="title"/>
# <meta content="인공지능 검색결과 | 교보문고" property="og:title"/>
# <meta content="꿈을 키우는 세상 교보문고는 온오프라인을 통틀어 대한민국 최고의 도서쇼핑몰이며 전자책, 음반, 기프트, 문화서비스까지 제공하는 종합문화기업입니다." name="description"/>
# <meta content="꿈을 키우는 세상 교보문고는 온오프라인을 통틀어 대한민국 최고의 도서쇼핑몰이며 전자책, 음반, 기프트, 문화서비스까지 제공하는 종합문화기업입니다." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo@2x.png" property="og:image"/>
# <meta content="http://mobile.kyobobook.co.kr" property="og:url"/>
# <meta content="date=no" name="format-detection"/>
# <meta content="2dlgBOp3K0s6wHjZo_Hkas6yaYPKZIVsmres9vC3F34" name="google-site-verification"/>
# <meta content="vN9Zag6odZ4sMyJfDMMSZTqbD-nbmnh0ituV4pk4FV4" name="google-site-verification"/>
# <meta content="AHqpy7PvqPoZwSySpolatuTj8M3B9F10Pi6UCldP5hE" name="google-site-verification"/>
# <meta content="ezckujv1qppxlglsp8fsry2bs2cw0n" name="facebook-domain-verification"/>
# <meta content="bef3d190b10f8cada477f5531d206cc1a799c498" name="naver-site-verification"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_256x256.png" rel="icon" sizes="256x256" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_196x196.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_128x128.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_48x48.png" rel="icon" sizes="48x48" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <meta content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-144x144-precomposed.png" name="msapplication-TileImage"/>
# <meta content="#222222" name="msapplication-TileColor"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-700x700-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="700x700"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="180x180"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-167x167-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="167x167"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="152x152"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="144x144"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="120x120"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="114x114"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-80x80-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="80x80"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="72x72"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="60x60"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon-precomposed"/>
# <title>인공지능 검색결과 | 교보문고</title>
# <link href="https://fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@400;500;700&amp;family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery-ui.min.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/vendors/swiper/v4/swiper.min.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/vendors/simplebar/5.3.3/simplebar.min.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/css/loading.css" rel="stylesheet"/>
# <link data-name="kbb-cm-style" href="https://contents.kyobobook.co.kr/resources/fo/css/style_ink.css?t=202507231211" rel="stylesheet" type="text/css"/>
# <script src="https://contents.kyobobook.co.kr/resources/vendors/essential-vendors.min.js"></script>
# <script data-name="jquery-ui" src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery-ui.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/vendors/jquery-ui-1.12.1/jquery.ui.spinner.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/vendors/lottie-5.9.4/lottie.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-loading.js?t=202507231211" type="text/javascript"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/kbbjs-loader-v2.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb.shared.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.shared.js?t=202507231211" type="text/javascript"></script>
# <script src="/web/js/kyobo_search_auto.js?t=202507231211" type="text/javascript"></script>
# <script>
#     // IIFE
#     ;(function () {
#         // --------------------- [KbbJS/SSR] 서버 환경변수 전달
#         const CDN_URL = "https:\/\/contents.kyobobook.co.kr\/resources\/fo"
#
#         const tmpArr = CDN_URL.match(/((https?:)?\/\/[^/]+)(\/.*)/)
#         const cdnHost = tmpArr[1]
#         const cdnBaseURL = tmpArr[3]
#
#         KbbJS.setOption('service.cdn.host', cdnHost)
#         KbbJS.setOption('service.cdn.baseURL', cdnBaseURL)
#
#         /**
#          * KbbJS 라이브러리 경로 설정
#          */
#         let KbbjsURL = "\/lib\/kbb-js"
#         if (!/^(https?:|\/\/)/.test(KbbjsURL)) {
#             KbbjsURL = CDN_URL + KbbjsURL
#         }
#
#         const KBBJS_VER = "v2.0\/latest"
#         if (KBBJS_VER != null) {
#             KbbjsURL += '/' + KBBJS_VER
#         } else {
#             KbbjsURL = "https:\/\/search.kyobobook.co.kr\/lib\/kbb-js"
#         }
#
#         // KbbJS 배포 개선 작업 1차 - 속성 추가
#         KbbJS.setOption('loader.bootstamp', "202507231211")
#         KbbJS.setOption('loader.baseURL', KbbjsURL)
#
#         // 인증여부 속성 추가
#         KbbJS.setOption('loader.authorized', false)
#         KbbJS.setOption('loader.user.nickname', null)
#         KbbJS.setOption('loader.user.picture', null)
#
#         // 디바이스 정보 설정
#         KbbJS.setOption('ua.device', {
#             isMobile: false,
#             isMobileApp: false,
#             isIOS: false,
#             isAndroid: false,
#             isMSIE: false,
#             isMac: false
#         })
#
#         /**
#          * 서비스 호스트 설정
#          */
#         const oServiceData = {"hosts":{"ebook-product":"https:\/\/ebook-product.kyobobook.co.kr","semo":"https:\/\/semo.kyobobook.co.kr","product":"https:\/\/product.kyobobook.co.kr","ecash":"https:\/\/ecash.kyobobook.co.kr","elibrary":"https:\/\/elibrary.kyobobook.co.kr","best":"https:\/\/best.kyobobook.co.kr","bookcast":"https:\/\/casting.kyobobook.co.kr","store":null,"undefined":null,"search":"https:\/\/search.kyobobook.co.kr","ebook":"https:\/\/ebook.kyobobook.co.kr","member":"https:\/\/mmbr.kyobobook.co.kr","myroom":"https:\/\/my.kyobobook.co.kr","event":"https:\/\/event.kyobobook.co.kr","welcome":"https:\/\/www.kyobobook.co.kr","hottracks":"https:\/\/hottracks.kyobobook.co.kr\/","sam":"https:\/\/sam.kyobobook.co.kr","order":"https:\/\/order.kyobobook.co.kr"}}
#         const oServiceHosts = _.get(oServiceData, 'hosts', {})
#         _.forEach(_.keys(oServiceHosts), function (key) {
#             let prop = key
#             switch (key.toLowerCase()) {
#                 case 'ebookproduct':
#                 case 'ebook-product':
#                     prop = 'ebookProduct';
#                     break
#                 case 'elibrary':
#                     prop = 'eLibrary'
#                     break
#             }
#             let value = _.get(oServiceHosts, key)
#             if (value == null) {
#                 // 기본 호스트 설정
#                 switch (key.toLowerCase()) {
#                     case 'welcome': value = 'www'; break
#                     case 'myroom': value = 'my'; break
#                     case 'bookcast': value = 'casting'; break
#                     case 'member': value = 'mmbr'; break
#                     case 'ebookproduct':
#                     case 'ebook-product':
#                         value = 'ebook-product'
#                         break
#                     case 'elibrary':
#                         value = 'elibrary'
#                         break
#                     case 'product':
#                     case 'event':
#                     case 'order':
#                     case 'search':
#                     case 'best':
#                     case 'ebook':
#                     case 'sam':
#                     case 'store':
#                     case 'ecash':
#                         value = prop
#                         break
#                 }
#                 if (value == null) return
#                 value = 'https://' + value + '.kyobobook.co.kr'
#             }
#             KbbJS.setOption('service.' + prop + '.host', value)
#         })
#     }())
# </script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-netfunnel.js?t=202507231211" type="text/javascript"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/common-vars.js?t=202507231211" type="text/javascript"></script>
# <script data-name="vars.common" src="https://contents.kyobobook.co.kr/resources/fo/js/vars/common.js?t=202507231211" type="text/javascript"></script>
# <script data-name="vars.service" src="https://contents.kyobobook.co.kr/resources/fo/js/vars/paper.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb.stats.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.stats.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb.gautil.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.gautil.js?t=202507231211" type="text/javascript"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/common-vars.js?t=202507231211" type="text/javascript"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/util.js?t=202507231211" type="text/javascript"></script>
# <script src="/web/js/kyobo_search_common.js?t=202507231211" type="text/javascript"></script>
# <script defer="" src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-cubot-loader.js?t=1753323413324" type="text/javascript"></script>
# <script data-name="kbb-vendors.min.js" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/vendors.min.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb-shared.min.js" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/shared.min.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb-components.min.js" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/components.min.js?t=202507231211" type="text/javascript"></script>
# <script data-name="kbb-core.min.js" src="https://contents.kyobobook.co.kr/resources/fo/lib/kbb-js/v2.0/latest/core.min.js?t=202507231211" type="text/javascript"></script>
# </head>
# <body>
# <div class="loading_box show" id="KbbLoading">
# <div class="loading_box_inner">
# <div class="loading_target"></div>
# </div>
# <div class="loading_dimmed"></div>
# </div>
# <div class="skip_nav_wrap">
# <a href="#contents">본문 바로가기</a>
# </div>
# <div class="wrapper contents_search_result" id="mainDiv">
# <!--
#             - 2024.02.05 PC인 경우 통합 GNB로 변경
#             - #TODO 모바일 통합 GNB 적용
#             -->
# <header class="header_wrapper has_banner header_v2 united_header mall_book sps" id="welcome_header_wrap">
# <!--
#     <th:block th:if="${(alCode=='EET'||alCode=='EMT'||alCode=='EHT'||alCode=='EAT') and alBannerGbn!='true'}">
#         <div class="top_banner_wrap" id="welcome_top_banner">
#             <div class="top_banner_inner">
#                 <a href="https://event.kyobobook.co.kr/detail/206105"><img class="img_top_banner" src="https://contents.kyobobook.co.kr/pmtn/2023/book/230104_ebs/bn/bnM_02.png" alt="EBS X 교보문고 고객님을 위한 5천원 열공 혜책!"></a>
#                 <button type="button" class="btn_close_banner">배너 닫기</button>
#             </div>
#         </div>
#     </th:block>
#     -->
# <div class="service_mall_wrap">
# <div class="service_mall_inner">
# <div class="service_mall_box">
# <ul class="service_mall_list">
# <li class="service_mall_item tab book"><a class="service_mall_link" href="https://www.kyobobook.co.kr/">교보문고</a></li>
# <li class="service_mall_item tab ebook"><a class="service_mall_link" href="https://ebook.kyobobook.co.kr/">eBook</a></li>
# <li class="service_mall_item tab sam"><a class="service_mall_link" href="https://sam.kyobobook.co.kr/">sam</a></li>
# <li class="service_mall_item tab hottracks"><a class="service_mall_link" href="https://hottracks.kyobobook.co.kr/ht/welcomeMain">핫트랙스</a></li>
# <li class="service_mall_item tab link"><a class="service_mall_link" href="https://storynew.kyobobook.co.kr/story/main/initMain.ink" target="_blank">스토리</a></li>
# <li class="service_mall_item brand_more"><button class="btn_brand_more" type="button"><span class="text">브랜드 더보기</span></button>
# <div class="brand_more_list_box">
# <div class="custom_scroll_wrap">
# <ul class="brand_more_list">
# <li class="brand_more_item"><a class="brand_more_link" href="https://product.kyobobook.co.kr/pod/main"><span class="img_box"><img alt="바로출판 BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_pod@2x.png"/></span><span class="brand_name">바로출판</span></a></li>
# <li class="brand_more_item"><a class="brand_more_link" href="https://readlog.kyobobook.co.kr/intro" target="_blank"><span class="img_box"><img alt="리드로그 BI" loading="lazy" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_readlog@2x.png"/></span><span class="brand_name">리드로그</span></a></li>
# </ul>
# </div>
# </div></li>
# </ul>
# </div>
# <div class="customer_service_box">
# <ul class="customer_service_list">
# <li class="customer_service_item" style="display:none"><a class="util_link" href="https://mmbr.kyobobook.co.kr/join">회원가입</a></li>
# <li class="customer_service_item" style="display:none"><a class="util_link" href="https://mmbr.kyobobook.co.kr/login">로그인</a></li>
# <li class="customer_service_item member_benefit"><button class="btn_member_benefit" type="button"><span class="text">회원혜택</span></button>
# <ul class="member_benefit_list">
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit">교보북클럽</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/grade">등급 혜택</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/new">신규회원 혜택</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/prestige">Prestige Lounge</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/discount">제휴 혜택</a></li>
# </ul></li>
# <li class="customer_service_item order"><a class="util_link" href="https://order.kyobobook.co.kr/myroom/member/order-list">주문배송</a></li>
# <li class="customer_service_item store"><a class="util_link" href="https://store.kyobobook.co.kr/store-info/001">매장안내</a></li>
# <li class="customer_service_item"><a class="util_link" href="https://www.kyobobook.co.kr/cscenter">고객센터</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="header_inner">
# <div class="gnb_search_wrap">
# <div class="logo_box"> <a class="logo_link book" href="https://www.kyobobook.co.kr/"><span class="hidden">교보문고</span></a>
# </div>
# <div class="gnb_search_box">
# <div class="form_sel" data-class="type_gnb"> <select id="gbCode" title="검색유형선택"><option value="TOT">통합검색</option><option value="KBO">교보문고</option><option value="EBK">eBook</option><option value="SAM">sam</option><option value="HTS">핫트랙스</option></select>
# </div>
# <div class="search_input_wrap">
# <input autocomplete="off" class="ip_gnb_search" id="searchKeyword" placeholder="검색어를 입력해주세요." title="통합검색어 입력" type="search" value=""/>
# <input id="searchBoxEventurl" name="searchBoxEventurl" type="hidden" value=""/>
# <script>jQuery(function () {
#     jQuery.getJSON('/api/adv?url=/INK/ink_wel_new/ink_wel@wel_02?callback=', function (data) {
#         var search_placeholder_txt = document.createElement('textarea');
#         search_placeholder_txt.innerHTML = data[0].text;
#         $(".ip_gnb_search").attr("placeholder", search_placeholder_txt.value);
#         $('#searchBoxEventurl').val(data[0].linkUrl);
#
#         setGtmForPlaceholder(data);
#     });
#   });</script><button class="btn_ip_clear" type="button"><span class="hidden">초기화</span></button>
# </div><a class="btn_gnb_search" data-role="gnb-search-submit" href="javascript:goAutoSearchLayer()"><span class="hidden">검색</span></a>
# </div>
# <ul class="user_menu_list">
# <li class="user_menu_item cash"><a class="user_menu_link" href="https://ecash.kyobobook.co.kr/dig/opr/ecash/general" title="e캐시"><span class="hidden">e캐시</span></a></li>
# <li class="user_menu_item library"><a class="user_menu_link" href="https://elibrary.kyobobook.co.kr/dig/elb/elibrary" title="내서재"><span class="hidden">내서재</span></a></li>
# <li class="user_menu_item cart"><a class="user_menu_link" href="https://order.kyobobook.co.kr/cart" title="장바구니"><span class="hidden">장바구니</span><span class="cnt" data-kbbfn="cart-size" style="display:none"></span></a></li>
# <li class="user_menu_item my"><a class="profile-icon user_menu_link done" data-render="ssr" href="https://my.kyobobook.co.kr/main" title="프로필"><span class="img_box no_img"><img alt="로그인"/></span><span class="hidden">프로필</span></a><script src="https://contents.kyobobook.co.kr/resources/fo/js/user-profile.js"></script></li>
# </ul>
# <div class="auto_complete_wrap auto_complete_maintain" id="hFrame">
# <div class="search_content_wrap inKeyword">
# <div class="scroll_wrap"></div>
# </div>
# <div class="search_content_wrap noKeyword">
# <div class="scroll_wrap">
# <div class="recommend_keyword_area">
# <div class="title_wrap title_size_def">
# <p class="title_heading">추천 검색어</p>
# </div>
# <div class="tag_wrap" id="recommendKeywordBox"></div>
# </div>
# <div class="keyword_contents_area">
# <div class="recent_keyword_box"></div>
# <div class="keyword_prod_box" id="keyWordProdBox"></div>
# <div class="hot_keyword_box" id="hotKeywordBox">
# <div class="title_wrap title_size_def">
# <p class="title_heading">실시간 인기 검색어</p>
# <div class="right_area"></div>
# </div>
# <div class="hot_keyword_list_wrap"></div>
# </div>
# </div>
# </div>
# <div class="util_area">
# <div class="util_button_area"> <a class="btn_xs" href="javascript:goCsCenter();"><span class="ico_link"></span><span class="text">도움말</span></a><a class="btn_xs" href="javascript:goDetailSearch();"><span class="ico_search"></span><span class="text">상세검색</span></a>
# </div><button class="button_layer_close" id="close_search_auto" type="button"><span class="text">닫기</span></button>
# </div>
# </div>
# </div>
# </div>
# <nav class="gnb_wrap">
# <div class="anb_wrap"> <button class="btn_anb" type="button"><span class="hidden">전체메뉴</span></button>
# <div class="anb_area">
# <div class="tab_wrap">
# <div class="tab_list_wrap">
# <ul class="tabs">
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategory"><span class="tab_text">카테고리 전체보기</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbService"><span class="tab_text">서비스 전체보기</span></a></li>
# </ul>
# </div>
# <div class="tab_content" id="tabAnbCategory">
# <div class="tab_wrap type_md channel">
# <div class="tab_list_wrap">
# <ul class="tabs">
# <li class="tab_item ui-tabs-active ui-state-active"><a class="tab_link" href="#tabAnbCategoryKyobo"><span class="tab_text">교보문고</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategoryEbook"><span class="tab_text">eBook</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategorySam"><span class="tab_text">sam</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategoryHotTracks"><span class="tab_text">핫트랙스</span></a></li>
# </ul>
# </div>
# <div class="tab_content anb_category" id="tabAnbCategoryKyobo">
# <div class="anb_category_inner">
# <div class="tab_wrap category">
# <div class="tab_list_wrap">
# <ul class="tabs">
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategorySub00"><span class="tab_text">국내도서</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategorySub01"><span class="tab_text">서양도서</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategorySub02"><span class="tab_text">일본도서</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategorySub03"><span class="tab_text">교보Only</span></a></li>
# </ul>
# </div>
# <div class="tab_content has_banner" id="tabAnbCategorySub00">
# <div class="custom_scroll_wrap">
# <div class="category_view_area"> <a class="btn_arw_link" href="https://product.kyobobook.co.kr/" target="_self"><span class="text">국내도서 전체</span></a>
# <div class="fold_box_wrap category">
# <div class="col_area">
# <ul class="fold_box_list">
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/01" target="_self">소설</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0101" target="_self">한국소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0103" target="_self">영미소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0105" target="_self">일본소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0107" target="_self">중국소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0109" target="_self">러시아소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0111" target="_self">프랑스소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0112" target="_self">독일소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0115" target="_self">북유럽소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0116" target="_self">그외유럽소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0117" target="_self">기타나라소설</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0121" target="_self">고전소설/문학선</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0124" target="_self">세계문학전집</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0126" target="_self">라이트노벨</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0128" target="_self">장르소설</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/03" target="_self">시/에세이</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0301" target="_self">한국시</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0302" target="_self">해외시</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0304" target="_self">테마에세이</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0307" target="_self">나라별 에세이</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0311" target="_self">인물/자전적에세이</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0317" target="_self">청소년 시/에세이</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0319" target="_self">시/에세이문고</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/05" target="_self">인문</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0501" target="_self">인문학일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0503" target="_self">심리학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0505" target="_self">교육학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0507" target="_self">유아교육</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0509" target="_self">특수교육</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0511" target="_self">임용고시</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0513" target="_self">철학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0515" target="_self">문학이론</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0517" target="_self">한국문학론</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0519" target="_self">영미문학론</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0520" target="_self">중국문학론</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0521" target="_self">세계문학론</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0523" target="_self">언어학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0525" target="_self">독서/글쓰기</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0527" target="_self">문헌정보학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0529" target="_self">역학/사주</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0532" target="_self">대학교재</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0533" target="_self">인문교양총서</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0535" target="_self">인문고전총서</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0551" target="_self">방송통신대교재</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/07" target="_self">가정/육아</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0701" target="_self">결혼/가정</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0703" target="_self">임신/출산</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0704" target="_self">육아</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0705" target="_self">자녀교육</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0707" target="_self">살림의지혜</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0709" target="_self">홈인테리어</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/08" target="_self">요리</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0801" target="_self">요리일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0802" target="_self">요리에세이</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0803" target="_self">테마별요리</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0805" target="_self">베이킹/간식</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0807" target="_self">계절요리</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0809" target="_self">재료별요리</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0811" target="_self">나라별요리</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0813" target="_self">생활요리</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0815" target="_self">전문요리</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0817" target="_self">와인/커피/음료</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0819" target="_self">요리수험서</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/09" target="_self">건강</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0901" target="_self">건강일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0903" target="_self">뇌건강</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0905" target="_self">한방치료</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0907" target="_self">자연건강</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0908" target="_self">건강식사</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0909" target="_self">질병치료/예방</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0911" target="_self">다이어트</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0913" target="_self">운동/트레이닝</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0915" target="_self">피부관리/메이크업</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0920" target="_self">건강문고</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/11" target="_self">취미/실용/스포츠</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1101" target="_self">가정원예</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1102" target="_self">홈인테리어/수납</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1103" target="_self">생활공예/DIY</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1104" target="_self">살림의지혜</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1105" target="_self">반려동물</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1107" target="_self">등산/낚시</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1109" target="_self">바둑/골프</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1113" target="_self">무술</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1115" target="_self">스포츠</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1117" target="_self">레크레이션/게임</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1118" target="_self">퀴즈/퍼즐/스도쿠</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1119" target="_self">무용</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1121" target="_self">체육</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1124" target="_self">취미일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1125" target="_self">취미관련상품</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1130" target="_self">대학교재</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/13" target="_self">경제/경영</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1301" target="_self">경영일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1303" target="_self">경영이론</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1305" target="_self">경영관리</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1307" target="_self">경영전략</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1309" target="_self">경제일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1311" target="_self">경제이론</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1313" target="_self">경제실무</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1315" target="_self">각국경제</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1316" target="_self">세무/회계</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1319" target="_self">마케팅/광고/고객</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1321" target="_self">유통/창업</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1323" target="_self">재테크/금융</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1325" target="_self">무역/운송</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1327" target="_self">관광/호텔</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1329" target="_self">경제/경영문고</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1331" target="_self">대학교재</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/15" target="_self">자기계발</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1501" target="_self">성공/처세</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1503" target="_self">자기능력계발</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1505" target="_self">비즈니스능력계발</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1506" target="_self">인간관계</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1507" target="_self">화술/협상</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1508" target="_self">청소년자기계발</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1509" target="_self">오디오북</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1519" target="_self">전자책단말기/전자기기</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/17" target="_self">정치/사회</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1701" target="_self">정치/외교</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1703" target="_self">행정/정책</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1705" target="_self">국방/군사</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1707" target="_self">법학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1709" target="_self">사회학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1711" target="_self">사회문제/복지</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1713" target="_self">언론/신문/방송</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1715" target="_self">정치/사회문고</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1717" target="_self">대학교재</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1720" target="_self">정부간행물</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/19" target="_self">역사/문화</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1901" target="_self">역사일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1903" target="_self">세계사</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1905" target="_self">서양사</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1907" target="_self">동양사</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1909" target="_self">한국사</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1911" target="_self">신화</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1912" target="_self">민속학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1913" target="_self">문화일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1915" target="_self">문화사</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1917" target="_self">역사인물</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1918" target="_self">역사기행</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1919" target="_self">청소년 역사</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1920" target="_self">지리학</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/1921" target="_self">대학교재</a></li>
# </ul>
# </div></li>
# </ul>
# </div>
# <div class="col_area">
# <ul class="fold_box_list">
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/21" target="_self">종교</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2101" target="_self">종교일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2103" target="_self">기독교(개신교)</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2105" target="_self">가톨릭</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2107" target="_self">불교</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2109" target="_self">그외종교</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2111" target="_self">CD/TAPE/악보</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/23" target="_self">예술/대중문화</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2301" target="_self">예술일반</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2303" target="_self">미술</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2305" target="_self">만화/애니메이션</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2307" target="_self">디자인/색채</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2309" target="_self">패션/의류</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2313" target="_self">음악</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2315" target="_self">사진/영상</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2317" target="_self">연극</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2319" target="_self">영화</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2320" target="_self">예술기행</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2321" target="_self">예술문고</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2325" target="_self">청소년예술</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2327" target="_self">대학교재</a></li>
# </ul>
# </div></li>
# <li class="fold_box">
# <div class="fold_box_header"> <a class="" href="https://product.kyobobook.co.kr/category/KOR/25" target="_self">중/고등참고서</a><button class="btn_fold" type="button"><span class="hidden">컨텐츠 열기</span></button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2501" target="_self">고등학교 출판사별</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2503" target="_self">고등학교 과목별</a></li>
# <li class="category_item"><a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/2505" target="_self">중학교 출판사별</a></li>
# ...
#                 }
#             </script>
# <!-- // 데이터 스크립트 전송 -->
# </div>
# <!-- //결과 영역 -->
# </div>
# <!-- EBS 이벤트 팝업 -->
# <!-- 메인팝업: 추가 230104 ebs제휴용 -->
# <link href="https://contents.kyobobook.co.kr/pmtn/2023/book/230104_ebs/ebs_lb.css" rel="stylesheet"/>
# <div class="dialog_wrap has_btn ebs_promo_layer" data-class="dialog_sm" id="popBurst"><!-- 230119 ebs_promo_layer 추가 -->
# <!-- inner -->
# <div class="ebs_inner">
# <div>
# <img alt="EBS X 교보문고 고객님을 위한 5,000원 열공 혜택!" src="https://contents.kyobobook.co.kr/pmtn/2024/book/240401_ebs/bnD2_01@2x.png"/>
# </div>
# <a class="btn_md btn_primary btn_pill" href="javascript:;" id="evtDtlBtn"><span class="text">자세히 보기</span></a>
# <div>
# <button class="btn_burst_close" id="ebsEventNextBtn" type="button">다음에 할래요</button>
# </div>
# </div>
# <!-- //inner -->
# </div>
# <!-- //메인팝업: 추가 230104 ebs제휴용 -->
# <script>
#     $(window).ready(function(){
#         var allienceCookie = getSearchCookie('LINK_CODE') == null ? getParam("LINK") : getSearchCookie('LINK_CODE');
#         var bannerCookie = getSearchCookie('ALLIENCE_BANNER');
#         var isEbs = allienceCookie === 'EET' ? 'true' : allienceCookie === 'EMT' ? 'true' : allienceCookie === 'EHT' ? 'true' : allienceCookie === 'EAT' ? 'true' : 'false';
#
#         if( isEbs === 'true' && getSearchCookie("ALLIENCE_BANNER") !== 'true'){
#             openPop("#popBurst");
#         }
#
#         var popTryMaxCnt = 10;
#         function openPop(_id){
#             setTimeout(function(){
#                 try{
#                     $(_id).dialog("open");
#                 }catch(e){
#                     console.log("popup not inicialized");
#                     if(--popTryMaxCnt > 0)
#                         openPop(_id);
#                 }
#             }, 1000); // 1초에 한번 실행
#         }
#     });
#
#     var eventUrl = ("https:\/\/event.kyobobook.co.kr\/") + (isDevHost() ? 'make/219585' : 'make/219585');
#     $("#evtDtlBtn").on("click", function(e){
#         location.href = eventUrl;
#     });
#     $("#ebsEventNextBtn").on("click", function(e){
#         setSearchCookie("ALLIENCE_BANNER","true",new Date(Date.now() + (1000*60*60*24)),'/','.kyobobook.co.kr');
#         $("#popBurst").dialog("close");
#     });
# </script>
# </div>
# <!-- //tab_content -->
# </div>
# <!-- //tab_wrap -->
# </div>
# </div>
# </section>
# <!-- // contents_wrap -->
# </main>
# <!-- 윙배너 -->
# <section class="fly_menu_wrapper sps" id="fly_wing_banner">
# <div class="fly_menu_inner">
# <a class="fly_menu_banner" href="javascript:void(0)" onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '배너', '');"><img/></a>
# <div class="fly_event_area">
# <a class="fly_menu_link" href="javascript:void(0)" onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '이벤트', '');">이벤트</a>
# <div class="fly_event_banner">
# <div class="swiper-container">
# <ul class="swiper-wrapper">
# </ul>
# </div>
# <div class="swiper_control_box">
# <button class="swiper-button-prev" type="button"><span class="hidden">이전</span></button>
# <div class="swiper-pagination"></div>
# <button class="swiper-button-next" type="button"><span class="hidden">다음</span></button>
# </div>
# </div>
# </div>
# <div class="fly_link_box">
# <a class="fly_menu_link" href="javascript:void(0)" id="wing_coupon" onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '쿠폰/혜택', '');">쿠폰/혜택</a>
# </div>
# </div>
# </section>
# <!-- // 윙배너 -->
# <div class="floating_wrapper" id="floating_wrapper">
# <div id="recent-contents" onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '최근본상품', '');"></div>
# <a class="btn_go_top" href="#top" title="최상위 화면으로">
# <span onclick="ga360.GA_Event('click_공통_PC', '사이드바', '', '맨위로', '');">TOP</span>
# </a>
# </div>
# <footer class="footer_wrapper" data-kbbfn="ui-module" data-kbbfn-name="footer-notice">
# <div class="footer_header default">
# <div class="footer_inner">
# <div class="notice_wrap">
# <span class="notice_text">공지사항</span>
# </div>
# <div class="notice_wrap winner">
# <span class="notice_text">당첨자발표</span>
# </div>
# </div>
# </div>
# <div class="footer_body">
# <div class="footer_inner">
# <div class="logo_box">
# <!-- <th:block th:insert="common/fragments/onk/logo :: main(logoPosition='footer')" /> -->
# <div class="logo_box">
# <a class="logo_link book" href="https://www.kyobobook.co.kr/">
# <img alt="KYOBO 교보문고" srcset="
#             https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo_footer.png 1x,
#             https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo_footer@1.5x.png 1.5x,
#             https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo_footer@2x.png 2x"/>
# </a>
# </div>
# <div class="right_box">
# <div class="family_site_box">
# <button class="btn_family_site" type="button"><span class="text">Family Site</span></button>
# <ul class="family_site_list">
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kyobo.com" target="_blank">교보생명</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.iprovest.com" target="_blank">교보증권</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kyobodts.co.kr" target="_blank">교보DTS</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kyoborealco.co.kr" target="_blank">교보리얼코</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kyoboaxa-im.co.kr" target="_blank">교보악사자산운용</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.lifeplanet.co.kr" target="_blank">교보라이프플래닛생명</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kcasonsa.co.kr" target="_blank">KCA 손해사정</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kcase.co.kr" target="_blank">KCA 서비스</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kyobotrust.co.kr" target="_blank">교보자산신탁주식회사</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="http://kyobo-aim.com/" target="_blank">교보AIM자산운용</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kyobodasomcare.com" target="_blank">교보다솜케어</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.andamc.com" target="_blank">A&amp;D신용정보</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.daesan.or.kr" target="_blank">대산문화재단</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.kbedu.or.kr" target="_blank">교보교육재단</a>
# </li>
# <li class="family_site_item">
# <a class="family_site_link" href="https://www.dsa.or.kr" target="_blank">대산농촌재단</a>
# </li>
# </ul>
# </div>
# <div class="sns_share_box">
# <a class="btn_sns_share youtube" href="https://www.youtube.com/c/kbooknews" target="_blank"><span class="hidden">youtube 공유</span></a>
# <a class="btn_sns_share fb" href="https://www.facebook.com/kyobobookonline?orderClick=rwk" target="_blank"><span class="hidden">facebook 공유</span></a>
# <a class="btn_sns_share insta" href="https://www.instagram.com/kyobobook_online/" target="_blank"><span class="hidden">instagram 공유</span></a>
# </div>
# </div>
# </div>
# <div class="footer_contents_wrap">
# <div class="footer_contents_left">
# <div class="footer_menu_box">
# <ul class="footer_menu_list">
# <li class="footer_menu_item">
# <a class="footer_menu_link" href="https://company.kyobobook.co.kr/ims/user/Intro/r/go?param=intro" target="_blank">회사소개</a>
# </li>
# <li class="footer_menu_item">
# <a class="footer_menu_link" href="https://www.kyobobook.co.kr/contents/provision">이용약관</a>
# </li>
# <li class="footer_menu_item privacy">
# <a class="footer_menu_link" href="https://www.kyobobook.co.kr/contents/privacy-policy">개인정보처리방침</a>
# </li>
# <li class="footer_menu_item">
# <a class="footer_menu_link" href="https://www.kyobobook.co.kr/contents/youth-policy">청소년보호정책</a>
# </li>
# <li class="footer_menu_item">
# <a class="footer_menu_link" href="https://big.kyobobook.co.kr">대량주문안내</a>
# </li>
# <li class="footer_menu_item">
# <a class="footer_menu_link" href="https://www.kyobobook.co.kr/partners/chargeperson">협력사여러분</a>
# </li>
# <li class="footer_menu_item">
# <a class="footer_menu_link" href="https://ehr.kyobobook.co.kr/recr/recruit_system_1.jsp" target="_blank">채용정보</a>
# </li>
# <li class="footer_menu_item">
# <a class="footer_menu_link" href="https://ad.kyobobook.co.kr" target="_blank">광고소개</a>
# </li>
# </ul>
# </div>
# <address class="footer_info_box">
# <span class="info_text">대표이사 : 허정도</span>
# <span class="gap">|</span>
# <span class="info_text">서울특별시 종로구 종로 1</span>
# <span class="gap">|</span>
# <span class="info_text">사업자등록번호 : 102-81-11670</span> <br/>
# <span class="info_text call">대표전화 : 1544-1900(발신자 부담전화)</span>
# <span class="gap">|</span>
# <span class="info_text">FAX : 0502-987-5711(지역번호 공통)</span>
# <span class="gap">|</span>
# <span class="info_text">서울특별시 통신판매업신고번호 : 제 653호</span>
# <a class="btn_footer_link" href="http://www.ftc.go.kr/info/bizinfo/communicationViewPopup.jsp?wrkr_no=1028111670" target="_blank">사업자정보확인</a>
# </address>
# <div class="copyright">
# <span>© KYOBO BOOK CENTRE</span>
# </div>
# </div>
# <div class="footer_contents_right">
# <div class="footer_service">
# <span class="service_text">토스페이먼츠 구매안전서비스 </span>
# <a class="btn_footer_link" href="https://pgweb.tosspayments.com/ms/escrow/s_escrowYn.do?mertid=ink0911" target="_blank">서비스 가입 확인</a>
# <p class="service_desc">
#                     고객님은 안전거래를 위해 현금 등으로 결제시 저희 쇼핑몰에서 가입한 <br/>
#                     토스페이먼츠의 구매안전서비스를 이용하실 수 있습니다.
#                 </p>
# </div>
# <div class="footer_mark_isms">
# <a class="mark_link" href="https://www.kyobobook.co.kr/pop_isms" target="_blank">
#         정보보호관리체계<br/>
#         ISMS 인증획득
#     </a>
# <p class="mark_desc">
#         [인증범위] 인터넷 교보문고 및 브랜드 서비스 운영<br/>
#         [유효기간] 2023.11.15 ~ 2026.11.14
#     </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <!-- LayerPopup area -->
# <!-- 스펙비교 레이어 팝업 -->
# <div class="spec_compare_layer_wrap">
# <div class="compare_layer_inner">
# <button class="btn_layer_close" onclick="closeSpecPopup()" type="button"><span class="ico_layer_close"></span><span class="hidden">닫기</span></button>
# <div class="compare_title_area">
# <div class="title_wrap title_size_md has_sub_title">
# <p class="title_heading">스펙비교</p>
# <p class="info_text">비교상품을 추가해보세요.</p>
# </div>
# <div class="compare_btn_box">
# <button class="btn_ip btn_line_gray" onclick="deleteAllSpecProd()" type="button"><span class="ico_delete"></span><span class="text">전체삭제</span></button>
# <a class="btn_ip btn_primary" href="javascript:goSpecComparePage();"><span class="text">스펙비교</span></a>
# </div>
# </div>
# <div class="compare_prod_area">
# <ul class="compare_prod_list" id="spec_compare_list">
# </ul>
# </div>
# </div>
# </div>
# <!-- //스펙비교 레이어 팝업 -->
# <!-- // LayerPopup area -->
# <script data-name="react-bundle" src="https://contents.kyobobook.co.kr/resources/vendors/react-bundle.min.js"></script>
# <!-- NetFUNNEL 스크립트 -->
# <script data-name="netfunnel" src="https://contents.kyobobook.co.kr/resources/vendors/netfunnel/custom-netfunnel.js"></script>
# <script data-name="ResizeSensor" src="https://contents.kyobobook.co.kr/resources/vendors/css-element-queries/ResizeSensor.js"></script>
# <script data-name="awesomplete" src="https://contents.kyobobook.co.kr/resources/vendors/awesomplete/awesomplete.min.js"></script>
# <script data-name="kbb.recent.js" src="https://contents.kyobobook.co.kr/resources/lib/kbb-js/kbb.recent.js?t=202507231211" type="text/javascript"></script>
# <script data-name="scrollPosStyler" src="https://contents.kyobobook.co.kr/resources/vendors/scrollpos-styler/scrollPosStyler.min.js"></script>
# <script data-name="blurify" src="https://contents.kyobobook.co.kr/resources/vendors/blurify-master/blurify.min.js"></script>
# <script data-name="masonry" src="https://contents.kyobobook.co.kr/resources/vendors/masonry/masonry.pkgd.min.js"></script>
# <script data-name="swiper" src="https://contents.kyobobook.co.kr/resources/vendors/swiper/v4/swiper.min.js"></script>
# <script data-name="svgxuse" src="https://contents.kyobobook.co.kr/resources/vendors/svgxuse/svgxuse.js"></script>
# <script data-name="simplebar" src="https://contents.kyobobook.co.kr/resources/vendors/simplebar/5.3.3/simplebar.min.js"></script>
# <script data-name="kbb-cm-script" src="https://contents.kyobobook.co.kr/resources/fo/js/ui_ink.js?t=202507231211" type="text/javascript"></script>
# <script src="/assets/js/vars.js?t=202507231211" type="text/javascript"></script>
# <script src="/common/js/kyobo_search_review.js?t=202507231211" type="text/javascript"></script>
# <script src="/web/js/kyobo_search_filter.js?t=202507231211" type="text/javascript"></script>
# <script src="/web/js/kyobo_search_spec.js?t=202507231211" type="text/javascript"></script>
# <script src="/common/js/kyobo_search_gtm.js?t=202507231211" type="text/javascript"></script>
# <script src="/common/js/kyobo_search_click_event.js?t=202507231211" type="text/javascript"></script>
# <script src="/common/js/kyobo_search_lazy.js?t=202507231211" type="text/javascript"></script>
# <!-- /* 큐봇(cubot) 스크립트 삽입 */-->
# <script>
#         const maxAttempts = 12;
#         const attemptInterval = 5000; // 5초
#
#         function initializeCuBotWidgetAsync(page) {
#             return new Promise((resolve, reject) => {
#                 let attempts = 0;
#
#                 function tryInitialize() {
#                     if (window.initializeCubotWidget) {
#                         window.initializeCubotWidget({page: page});
#                         resolve();
#                     } else if (attempts < maxAttempts) {
#                         setTimeout(tryInitialize, attemptInterval);
#                         attempts++;
#                     } else {
#                         reject();
#                     }
#                 }
#
#                 tryInitialize();
#             });
#         }
#
#         document.addEventListener('DOMContentLoaded', () => {
#             initializeCuBotWidgetAsync("search")
#                 .then(() => console.log('CuBot Widget initialized successfully'));
#         });
#     </script>
# </body>
# </html>

# %% [markdown]
# ## 3) 파싱

# %%
# ul 태그 : class가 prod_list
test = soup.find_all("ul", class_="prod_list")
print(len(test))    # len = 1
# 어차피 1개 이므로 find_all 말고 find로 찾아서 리스트에 넣자

prod_list = soup.find("ul", class_="prod_list")
# print(prod_list)
# Out:
# 1

# %%
# prod_list에서 li태그 : class가 prod_item
prod_item = soup.find_all("li", class_="prod_item")
print(prod_item)
# Out:
# [<li class="prod_item">
# <!-- 체크박스 영역 -->
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label">
# <!--교보일때-->
# <input class="result_checkbox spec_checkbox" data-bid="9788955685329" data-cdtn-code="008" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="인공지능입문" data-pid="S000217120455" data-prhb-age="0" id="chkSearch_S000217120455" name="001_001_S000217120455_chkSearchNm" type="checkbox"/>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <label for="chkSearch_S000217120455"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <!-- 상품 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box size_lg">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000217120455&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9788955685329" data-kbbfn-pid="S000217120455" data-kbbfn-size="200x0" data-kbbfn-title="인공지능입문" data-kbbfn-type="KOR"/>
# </span>
# </a>
# <div class="prod_viewer_control">
# <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000217120455&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
# </div>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- // 라벨 -->
# <!-- 상품명 -->
# <div class="auto_overflow_wrap prod_name_group">
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217120455&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span class="prod_label" id="gubun3_S000217120455">예약판매</span>
# <span id="cmdtName_S000217120455">인공지능입문</span>
# </a>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000217120455");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# <!-- LayerPopup area -->
# <!-- 타이틀 전체보기 -->
# <div class="dialog_wrap no_title" id="popAllProdTitle">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <div class="prod_detail_title_wrap">
# <!-- prod_title_area -->
# <div class="prod_title_area">
# <!-- 상품 타이틀 -->
# <div class="prod_title_box">
# <!-- DESC : 상품 타이틀 구분 값 케이스
#                         - 일반 구분 값 : .prod_label
#                         - 관칭관제 : .prod_alias
#                         - 상품명 : .prod_title
#                     -->
# <span class="prod_label" id="gubun1"></span>
# <span class="gap gubun2">·</span>
# <span class="prod_label" id="gubun2"></span>
# <span class="gap gubun3">·</span>
# <span class="prod_label" id="gubun3"></span>
# <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# <h1>
# <span class="prod_alias" id="kwch"></span>
# <span class="prod_title" id="cmdtName"></span>
# </h1>
# <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# </div>
# <!-- //상품 타이틀 -->
# </div>
# <!-- //prod_title_area -->
# <!-- prod_desc_area -->
# <div class="prod_desc_area">
# <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc" id="subtitle_1"></span>
# <span class="gap subtitle_2"> | </span>
# <span class="prod_desc" id="subtitle_2"></span>
# <span class="gap subtitle_3"> | </span>
# <span class="prod_desc" id="subtitle_3"></span>
# </div>
# <!-- //상품 부제명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc normal" id="splmCntt"></span>
# <span class="gap bkbnShpName"> | </span>
# <span class="prod_desc normal" id="bkbnShpName"></span>
# <span class="gap setCnfgCmdtQntt"> | </span>
# <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
# </div>
# <!-- //상품 부제명 -->
# </div>
# <!-- //prod_desc_area -->
# </div>
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- //타이틀 전체보기 -->
# <!-- // LayerPopup area -->
# </div>
# </div>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_info">
# <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
# <div class="auto_overflow_wrap prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@@\uC190\uCC3D\uD638|001@@\uC774\uC740\uC560");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# </div>
# <!--인물 페이지-->
# <!-- LayerPopup area -->
# <!-- 저자 모두보기 팝업 -->
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_header -->
# <div class="dialog_header">
# <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
# </div>
# <!-- //dialog_header -->
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <!-- form_wrap -->
# <div class="form_wrap type_md" id="authorBox">
# </div>
# <!-- //form_wrap -->
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <!-- //저자 모두보기 팝업 -->
# <!-- // LayerPopup area -->
# </div>
# <div class="prod_publish">
# <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</a>
# <span class="gap">·</span>
# <span class="date">2025년 07월 31일</span>
# </div>
# </div>
# <!-- // 저자, 출판사 정보 -->
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="percent">10%</span>
# <span class="price">
# <span class="val">12,600</span>
# <span class="unit">원 </span>
# </span>
# <span class="price_normal">
# <span class="text">정가</span>
# <s class="val">14,000원</s>
# </span>
# <span class="gap">|</span>
# <span class="point">
#                             700p
#                             <span class="rate">(5%)</span>
# </span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매중이 아닐떄-->
# <!--중고 장터일때-->
# <!--//가격정보 페이지-->
# <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <div class="prod_bottom">
# <!--좋아요 버튼(썸네일) 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon bottom" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217120455_CMDTCODE_VAL_BOTTOM">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
# <!--클로버리뷰-->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000217120455"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text font_size_xxs">0.0</span>
# <!--임시 조건-->
# <span class="review_desc">(0)</span>
# <!--//임시조건-->
# </span>
# <!--임시 조건-->
# <!--//임시조건-->
# </a>
# <!--//클로버리뷰-->
# </div>
# <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <!-- 태그 -->
# <div class="tag_wrap size_sm">
# </div>
# <!-- // 태그 -->
# <!-- 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# </div>
# </div>
# <!-- // 상품 영역 -->
# <!-- only list type -->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!-- 배송정보 영역 -->
# <!--바로드림 전용상품이 아닐경우-->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <!--<br> -->
# <span class="fw_bold">7/31(목)</span>
# <br/>
# <span>출고예정</span>
# <div class="tooltip_wrap type_sm right" id="tooltip_search">
# <button class="btn_tooltip" id="btn_tooltip_search" type="button">
# <span class="ico_info"></span>
# <span class="hidden">툴팁열기</span>
# </button>
# <div class="tooltip_inner" id="tooltip_content_search">
# <div class="tooltip_header">
# <div class="tooltip_head_title">검색결과 배송일자 기준 안내</div>
# </div>
# <div class="tooltip_contents">
# <div class="tooltip_desc">
#                                     '가장 빠른 배송지' 기준
#                                     <br/>
#                                     로그인 후 상품 상세 페이지, 주문/결제 페이지에서
#                                     <br/>
# <span class="fc_spot">정확한 배송 안내</span>
#                                     를 받아보세요.
#                                 </div>
# </div>
# <button class="btn_tooltip_close" id="btn_tooltip_close_search" type="button">
# <span class="hidden">툴팁 닫기</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 리스트형 타입 버튼영역 -->
# <div class="prod_btn_wrap">
# <!--결제기능, 좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217120455_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <div class="btn_wrap full">
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <a class="btn_sm btn_light_gray" href="javascript:;" onclick='searchResultCartClickEvent(false, "S000217120455");'><span class="text">장바구니</span></a>
# <a class="btn_sm btn_primary" href="javascript:;" onclick='searchResultDirectOrderClickEvent("S000217120455");'><span class="text">바로구매</span></a>
# <!--품절 상품일때-->
# <!--출시예정 상품일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '004'">
#                 <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000217120455, SGK, KOR);"><span class="ico_alarm"></span><span class="text">출시알림</span></button>
#             </th:block>-->
# <!--절판,품절,일시품절 일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                 <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                     <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000217120455, , KOR);"><span class="ico_alarm"></span>
#                         <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                         <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                     </button>
#                 </th:block>
#             </th:block>-->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# <!-- 앨범 일때-->
# <!--중고 장터일때-->
# </div>
# <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
# <ul class="prod_related_list">
#
#
#
# q
#
#
#
#
#                 </ul>
# </div>
# </li>, <li class="prod_item">
# <!-- 체크박스 영역 -->
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label">
# <!--교보일때-->
# <input class="result_checkbox spec_checkbox" data-bid="9791143007131" data-cdtn-code="008" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="인공지능과 죽음" data-pid="S000217098239" data-prhb-age="0" id="chkSearch_S000217098239" name="001_001_S000217098239_chkSearchNm" type="checkbox"/>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <label for="chkSearch_S000217098239"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <!-- 상품 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box size_lg">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000217098239" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000217098239&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791143007131" data-kbbfn-pid="S000217098239" data-kbbfn-size="200x0" data-kbbfn-title="인공지능과 죽음" data-kbbfn-type="KOR"/>
# </span>
# </a>
# <div class="prod_viewer_control">
# <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000217098239&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
# </div>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- // 라벨 -->
# <!-- 상품명 -->
# <div class="auto_overflow_wrap prod_name_group">
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217098239" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217098239&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span class="prod_label" id="gubun3_S000217098239">예약판매</span>
# <span id="cmdtName_S000217098239">인공지능과 죽음</span>
# </a>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000217098239");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# <!-- LayerPopup area -->
# <!-- 타이틀 전체보기 -->
# <div class="dialog_wrap no_title" id="popAllProdTitle">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <div class="prod_detail_title_wrap">
# <!-- prod_title_area -->
# <div class="prod_title_area">
# <!-- 상품 타이틀 -->
# <div class="prod_title_box">
# <!-- DESC : 상품 타이틀 구분 값 케이스
#                         - 일반 구분 값 : .prod_label
#                         - 관칭관제 : .prod_alias
#                         - 상품명 : .prod_title
#                     -->
# <span class="prod_label" id="gubun1"></span>
# <span class="gap gubun2">·</span>
# <span class="prod_label" id="gubun2"></span>
# <span class="gap gubun3">·</span>
# <span class="prod_label" id="gubun3"></span>
# <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# <h1>
# <span class="prod_alias" id="kwch"></span>
# <span class="prod_title" id="cmdtName"></span>
# </h1>
# <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# </div>
# <!-- //상품 타이틀 -->
# </div>
# <!-- //prod_title_area -->
# <!-- prod_desc_area -->
# <div class="prod_desc_area">
# <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc" id="subtitle_1"></span>
# <span class="gap subtitle_2"> | </span>
# <span class="prod_desc" id="subtitle_2"></span>
# <span class="gap subtitle_3"> | </span>
# <span class="prod_desc" id="subtitle_3"></span>
# </div>
# <!-- //상품 부제명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc normal" id="splmCntt"></span>
# <span class="gap bkbnShpName"> | </span>
# <span class="prod_desc normal" id="bkbnShpName"></span>
# <span class="gap setCnfgCmdtQntt"> | </span>
# <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
# </div>
# <!-- //상품 부제명 -->
# </div>
# <!-- //prod_desc_area -->
# </div>
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- //타이틀 전체보기 -->
# <!-- // LayerPopup area -->
# </div>
# </div>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# <span class="prod_desc">(인공지능총서)</span>
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_info">
# <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
# <div class="auto_overflow_wrap prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1001367001&quot;,&quot;\uC2EC\uD601\uC8FC&quot;);">심혁주</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@1001367001@\uC2EC\uD601\uC8FC");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# </div>
# <!--인물 페이지-->
# <!-- LayerPopup area -->
# <!-- 저자 모두보기 팝업 -->
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_header -->
# <div class="dialog_header">
# <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
# </div>
# <!-- //dialog_header -->
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <!-- form_wrap -->
# <div class="form_wrap type_md" id="authorBox">
# </div>
# <!-- //form_wrap -->
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <!-- //저자 모두보기 팝업 -->
# <!-- // LayerPopup area -->
# </div>
# <div class="prod_publish">
# <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB09525&quot;,&quot;\uCEE4\uBBA4\uB2C8\uCF00\uC774\uC158\uBD81\uC2A4&quot;);">커뮤니케이션북스</a>
# <span class="gap">·</span>
# <span class="date">2025년 07월 31일</span>
# </div>
# </div>
# <!-- // 저자, 출판사 정보 -->
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="percent">10%</span>
# <span class="price">
# <span class="val">10,800</span>
# <span class="unit">원 </span>
# </span>
# <span class="price_normal">
# <span class="text">정가</span>
# <s class="val">12,000원</s>
# </span>
# <span class="gap">|</span>
# <span class="point">
#                             600p
#                             <span class="rate">(5%)</span>
# </span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매중이 아닐떄-->
# <!--중고 장터일때-->
# <!--//가격정보 페이지-->
# <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <div class="prod_bottom">
# <!--좋아요 버튼(썸네일) 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9791143007131" data-pid="S000217098239" id="searchWishItemInfo_S000217098239" name="001_001_S000217098239_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon bottom" data-cmdtcode="9791143007131" id="S000217098239_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000217098239");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217098239_CMDTCODE_VAL_BOTTOM">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
# <!--클로버리뷰-->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000217098239"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text font_size_xxs">0.0</span>
# <!--임시 조건-->
# <span class="review_desc">(0)</span>
# <!--//임시조건-->
# </span>
# <!--임시 조건-->
# <!--//임시조건-->
# </a>
# <!--//클로버리뷰-->
# </div>
# <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <!-- 태그 -->
# <div class="tag_wrap size_sm">
# </div>
# <!-- // 태그 -->
# <!-- 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# </div>
# </div>
# <!-- // 상품 영역 -->
# <!-- only list type -->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!-- 배송정보 영역 -->
# <!--바로드림 전용상품이 아닐경우-->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <!--<br> -->
# <span class="fw_bold">7/29(화)</span>
# <br/>
# <span>출고예정</span>
# <div class="tooltip_wrap type_sm right" id="tooltip_search">
# <button class="btn_tooltip" id="btn_tooltip_search" type="button">
# <span class="ico_info"></span>
# <span class="hidden">툴팁열기</span>
# </button>
# <div class="tooltip_inner" id="tooltip_content_search">
# <div class="tooltip_header">
# <div class="tooltip_head_title">검색결과 배송일자 기준 안내</div>
# </div>
# <div class="tooltip_contents">
# <div class="tooltip_desc">
#                                     '가장 빠른 배송지' 기준
#                                     <br/>
#                                     로그인 후 상품 상세 페이지, 주문/결제 페이지에서
#                                     <br/>
# <span class="fc_spot">정확한 배송 안내</span>
#                                     를 받아보세요.
#                                 </div>
# </div>
# <button class="btn_tooltip_close" id="btn_tooltip_close_search" type="button">
# <span class="hidden">툴팁 닫기</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 리스트형 타입 버튼영역 -->
# <div class="prod_btn_wrap">
# <!--결제기능, 좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9791143007131" data-pid="S000217098239" id="searchWishItemInfo_S000217098239" name="001_001_S000217098239_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon" data-cmdtcode="9791143007131" id="S000217098239_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000217098239");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217098239_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <div class="btn_wrap full">
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <a class="btn_sm btn_light_gray" href="javascript:;" onclick='searchResultCartClickEvent(false, "S000217098239");'><span class="text">장바구니</span></a>
# <a class="btn_sm btn_primary" href="javascript:;" onclick='searchResultDirectOrderClickEvent("S000217098239");'><span class="text">바로구매</span></a>
# <!--품절 상품일때-->
# <!--출시예정 상품일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '004'">
#                 <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000217098239, SGK, KOR);"><span class="ico_alarm"></span><span class="text">출시알림</span></button>
#             </th:block>-->
# <!--절판,품절,일시품절 일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                 <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                     <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000217098239, , KOR);"><span class="ico_alarm"></span>
#                         <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                         <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                     </button>
#                 </th:block>
#             </th:block>-->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# <!-- 앨범 일때-->
# <!--중고 장터일때-->
# </div>
# <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
# <ul class="prod_related_list">
#
#
#
# q
#
#
#
#
#                 </ul>
# </div>
# </li>, <li class="prod_item">
# <!-- 체크박스 영역 -->
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label">
# <!--교보일때-->
# <input class="result_checkbox spec_checkbox" data-bid="9791163037231" data-cdtn-code="001" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="된다! 하루 만에 끝내는 챗GPT 활용법" data-pid="S000216645088" data-prhb-age="0" id="chkSearch_S000216645088" name="001_001_S000216645088_chkSearchNm" type="checkbox"/>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <label for="chkSearch_S000216645088"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <!-- 상품 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box size_lg">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000216645088" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000216645088&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791163037231" data-kbbfn-pid="S000216645088" data-kbbfn-size="200x0" data-kbbfn-title="된다! 하루 만에 끝내는 챗GPT 활용법" data-kbbfn-type="KOR"/>
# </span>
# </a>
# <div class="prod_viewer_control">
# <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000216645088&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
# </div>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <span class="badge_md badge_line_gray"><span class="text">이벤트</span></span>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- // 라벨 -->
# <!-- 상품명 -->
# <div class="auto_overflow_wrap prod_name_group">
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000216645088" onclick="searchResultItemClickEvent('상품 제목', &quot;S000216645088&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span id="cmdtName_S000216645088">된다! 하루 만에 끝내는 챗GPT 활용법</span>
# </a>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000216645088");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# <!-- LayerPopup area -->
# <!-- 타이틀 전체보기 -->
# <div class="dialog_wrap no_title" id="popAllProdTitle">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <div class="prod_detail_title_wrap">
# <!-- prod_title_area -->
# <div class="prod_title_area">
# <!-- 상품 타이틀 -->
# <div class="prod_title_box">
# <!-- DESC : 상품 타이틀 구분 값 케이스
#                         - 일반 구분 값 : .prod_label
#                         - 관칭관제 : .prod_alias
#                         - 상품명 : .prod_title
#                     -->
# <span class="prod_label" id="gubun1"></span>
# <span class="gap gubun2">·</span>
# <span class="prod_label" id="gubun2"></span>
# <span class="gap gubun3">·</span>
# <span class="prod_label" id="gubun3"></span>
# <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# <h1>
# <span class="prod_alias" id="kwch"></span>
# <span class="prod_title" id="cmdtName"></span>
# </h1>
# <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# </div>
# <!-- //상품 타이틀 -->
# </div>
# <!-- //prod_title_area -->
# <!-- prod_desc_area -->
# <div class="prod_desc_area">
# <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc" id="subtitle_1"></span>
# <span class="gap subtitle_2"> | </span>
# <span class="prod_desc" id="subtitle_2"></span>
# <span class="gap subtitle_3"> | </span>
# <span class="prod_desc" id="subtitle_3"></span>
# </div>
# <!-- //상품 부제명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc normal" id="splmCntt"></span>
# <span class="gap bkbnShpName"> | </span>
# <span class="prod_desc normal" id="bkbnShpName"></span>
# <span class="gap setCnfgCmdtQntt"> | </span>
# <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
# </div>
# <!-- //상품 부제명 -->
# </div>
# <!-- //prod_desc_area -->
# </div>
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- //타이틀 전체보기 -->
# <!-- // LayerPopup area -->
# </div>
# </div>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# <span class="prod_desc">인공지능에게 일 시키고 시간 버는 법 최신 버전 GPT 4.1 반영! (된다! 시리즈)<span class="gap"> | </span></span>
# <span class="prod_desc normal">전면개정판 3판</span>
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_info">
# <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
# <div class="auto_overflow_wrap prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1117520301&quot;,&quot;\uD504\uB86C\uD504\uD2B8 \uD06C\uB9AC\uC5D0\uC774\uD130&quot;);">프롬프트 크리에이터</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@1117520301@\uD504\uB86C\uD504\uD2B8 \uD06C\uB9AC\uC5D0\uC774\uD130");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# </div>
# <!--인물 페이지-->
# <!-- LayerPopup area -->
# <!-- 저자 모두보기 팝업 -->
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_header -->
# <div class="dialog_header">
# <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
# </div>
# <!-- //dialog_header -->
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <!-- form_wrap -->
# <div class="form_wrap type_md" id="authorBox">
# </div>
# <!-- //form_wrap -->
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <!-- //저자 모두보기 팝업 -->
# <!-- // LayerPopup area -->
# </div>
# <div class="prod_publish">
# <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB26874&quot;,&quot;\uC774\uC9C0\uC2A4\uD37C\uBE14\uB9AC\uC2F1&quot;);">이지스퍼블리싱</a>
# <span class="gap">·</span>
# <span class="date">2025년 06월 04일</span>
# </div>
# </div>
# <!-- // 저자, 출판사 정보 -->
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="percent">10%</span>
# <span class="price">
# <span class="val">18,000</span>
# <span class="unit">원 </span>
# </span>
# <span class="price_normal">
# <span class="text">정가</span>
# <s class="val">20,000원</s>
# </span>
# <span class="gap">|</span>
# <span class="point">
#                             1,000p
#                             <span class="rate">(5%)</span>
# </span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매중이 아닐떄-->
# <!--중고 장터일때-->
# <!--//가격정보 페이지-->
# <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <div class="prod_bottom">
# <!--좋아요 버튼(썸네일) 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9791163037231" data-pid="S000216645088" id="searchWishItemInfo_S000216645088" name="001_001_S000216645088_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon bottom" data-cmdtcode="9791163037231" id="S000216645088_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000216645088");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000216645088_CMDTCODE_VAL_BOTTOM">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
# <!--클로버리뷰-->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000216645088"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text font_size_xxs">9.89</span>
# <!--임시 조건-->
# <span class="review_desc">(38)</span>
# <!--//임시조건-->
# </span>
# <!--임시 조건-->
# <span class="gap">/</span>
# <span class="review_quotes_text font_size_xxs">도움돼요</span>
# <!--//임시조건-->
# </a>
# <!--//클로버리뷰-->
# </div>
# <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <!-- 태그 -->
# <div class="tag_wrap size_sm">
# <a class="tag" href="javascript:tagSearch('GPT-4.1','kyobo')">#GPT-4.1</a>
# </div>
# <!-- // 태그 -->
# <!-- 이벤트 정보 -->
# <!-- 이벤트 정보 -->
# <!--
#     (이벤트아이디@이벤트내용@이벤트구분|이벤트아이디@이벤트내용@이벤트구분)
#     이벤트 구분
#     001: 이벤트
#     002: 사은품
#     003: 경품
#     -->
# <div class="prod_gift_info"><a class="prod_gift_text" href="javascript:void(0);" onclick="goEventDetailPage(232030)">7월의 바로 이 책</a> 외 2건<div class="tooltip_wrap type_sm">
# <button class="btn_tooltip" type="button"><span class="ico_info"></span><span class="hidden">툴팁열기</span></button>
# <div class="tooltip_inner">
# <div class="tooltip_header">
# <div class="tooltip_head_title">이벤트 안내</div>
# </div>
# <div class="tooltip_contents"><div class="tooltip_sub_title">이벤트</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(237043)">2025 하반기 기대 신간 캘린더</a></li>
# </ul><div class="tooltip_sub_title">사은품</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(232030)">7월의 바로 이 책</a></li>
# </ul><div class="tooltip_sub_title">경품</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(236845)">🔐 읽는 친구끼리 비밀 교환 독서기록장 : 세 번째 기록, 방학 🏖️</a></li>
# </ul></div>
# <button class="btn_tooltip_close" type="button"><span class="hidden">툴팁닫기</span></button>
# </div>
# </div></div>
# <!-- // 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# </div>
# </div>
# <!-- // 상품 영역 -->
# <!-- only list type -->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!-- 배송정보 영역 -->
# <!--바로드림 전용상품이 아닐경우-->
# <div class="prod_order_state">
# <span class="badge_sm badge_pill badge_primary"><span class="text">당일배송</span></span>
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <!--<br> -->
# <span class="fw_bold">오늘(7/24, 목) </span>
# <br/>
# <span>도착</span>
# <div class="tooltip_wrap type_sm right" id="tooltip_search">
# <button class="btn_tooltip" id="btn_tooltip_search" type="button">
# <span class="ico_info"></span>
# <span class="hidden">툴팁열기</span>
# </button>
# <div class="tooltip_inner" id="tooltip_content_search">
# <div class="tooltip_header">
# <div class="tooltip_head_title">검색결과 배송일자 기준 안내</div>
# </div>
# <div class="tooltip_contents">
# <div class="tooltip_desc">
#                                     '가장 빠른 배송지' 기준
#                                     <br/>
#                                     로그인 후 상품 상세 페이지, 주문/결제 페이지에서
#                                     <br/>
# <span class="fc_spot">정확한 배송 안내</span>
#                                     를 받아보세요.
#                                 </div>
# </div>
# <button class="btn_tooltip_close" id="btn_tooltip_close_search" type="button">
# <span class="hidden">툴팁 닫기</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 리스트형 타입 버튼영역 -->
# <div class="prod_btn_wrap">
# <!--결제기능, 좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9791163037231" data-pid="S000216645088" id="searchWishItemInfo_S000216645088" name="001_001_S000216645088_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon" data-cmdtcode="9791163037231" id="S000216645088_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000216645088");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000216645088_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <div class="btn_wrap full">
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <a class="btn_sm btn_light_gray" href="javascript:;" onclick='searchResultCartClickEvent(false, "S000216645088");'><span class="text">장바구니</span></a>
# <a class="btn_sm btn_line_primary" href="javascript:;" onclick='searchResultDirectPickUpClickEvent("S000216645088");'><span class="text">바로드림</span></a>
# <a class="btn_sm btn_primary" href="javascript:;" onclick='searchResultDirectOrderClickEvent("S000216645088");'><span class="text">바로구매</span></a>
# <!--품절 상품일때-->
# <!--출시예정 상품일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '004'">
#                 <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000216645088, SGK, KOR);"><span class="ico_alarm"></span><span class="text">출시알림</span></button>
#             </th:block>-->
# <!--절판,품절,일시품절 일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                 <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                     <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000216645088, , KOR);"><span class="ico_alarm"></span>
#                         <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                         <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                     </button>
#                 </th:block>
#             </th:block>-->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# <!-- 앨범 일때-->
# <!--중고 장터일때-->
# </div>
# <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
# <ul class="prod_related_list">
# <li class="btn_item">
# <a class="btn_xxs btn_pill btn_line_gray" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000011576683" onclick="searchResultItemClickEvent('eBook', &quot;S000216645088&quot;);">
# <span class="text">eBook</span><span class="ico_arw"></span>
# </a>
# </li>
#
# q
#
#
#
#
#                 </ul>
# </div>
# </li>, <li class="prod_item">
# <!-- 체크박스 영역 -->
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label">
# <!--교보일때-->
# <input class="result_checkbox spec_checkbox" data-bid="9788965404026" data-cdtn-code="001" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="AI 리터러시: 인공지능 필수 지식부터 완벽 활용까지" data-pid="S000214845678" data-prhb-age="0" id="chkSearch_S000214845678" name="001_001_S000214845678_chkSearchNm" type="checkbox"/>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <label for="chkSearch_S000214845678"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <!-- 상품 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box size_lg">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000214845678" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000214845678&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9788965404026" data-kbbfn-pid="S000214845678" data-kbbfn-size="200x0" data-kbbfn-title="AI 리터러시: 인공지능 필수 지식부터 완벽 활용까지" data-kbbfn-type="KOR"/>
# </span>
# </a>
# <div class="prod_viewer_control">
# <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000214845678&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
# </div>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <span class="badge_md badge_line_gray"><span class="text">이벤트</span></span>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- // 라벨 -->
# <!-- 상품명 -->
# <div class="auto_overflow_wrap prod_name_group">
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000214845678" onclick="searchResultItemClickEvent('상품 제목', &quot;S000214845678&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span id="cmdtName_S000214845678">AI 리터러시: 인공지능 필수 지식부터 완벽 활용까지</span>
# </a>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000214845678");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# <!-- LayerPopup area -->
# <!-- 타이틀 전체보기 -->
# <div class="dialog_wrap no_title" id="popAllProdTitle">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <div class="prod_detail_title_wrap">
# <!-- prod_title_area -->
# <div class="prod_title_area">
# <!-- 상품 타이틀 -->
# <div class="prod_title_box">
# <!-- DESC : 상품 타이틀 구분 값 케이스
#                         - 일반 구분 값 : .prod_label
#                         - 관칭관제 : .prod_alias
#                         - 상품명 : .prod_title
#                     -->
# <span class="prod_label" id="gubun1"></span>
# <span class="gap gubun2">·</span>
# <span class="prod_label" id="gubun2"></span>
# <span class="gap gubun3">·</span>
# <span class="prod_label" id="gubun3"></span>
# <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# <h1>
# <span class="prod_alias" id="kwch"></span>
# <span class="prod_title" id="cmdtName"></span>
# </h1>
# <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# </div>
# <!-- //상품 타이틀 -->
# </div>
# <!-- //prod_title_area -->
# <!-- prod_desc_area -->
# <div class="prod_desc_area">
# <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc" id="subtitle_1"></span>
# <span class="gap subtitle_2"> | </span>
# <span class="prod_desc" id="subtitle_2"></span>
# <span class="gap subtitle_3"> | </span>
# <span class="prod_desc" id="subtitle_3"></span>
# </div>
# <!-- //상품 부제명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc normal" id="splmCntt"></span>
# <span class="gap bkbnShpName"> | </span>
# <span class="prod_desc normal" id="bkbnShpName"></span>
# <span class="gap setCnfgCmdtQntt"> | </span>
# <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
# </div>
# <!-- //상품 부제명 -->
# </div>
# <!-- //prod_desc_area -->
# </div>
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- //타이틀 전체보기 -->
# <!-- // LayerPopup area -->
# </div>
# </div>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# <span class="prod_desc">여전히 챗GPT만 붙들고 있는 당신에게</span>
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_info">
# <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
# <div class="auto_overflow_wrap prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1000093814&quot;,&quot;\uAE40\uC6A9\uC131&quot;);">김용성</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@1000093814@\uAE40\uC6A9\uC131");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# </div>
# <!--인물 페이지-->
# <!-- LayerPopup area -->
# <!-- 저자 모두보기 팝업 -->
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_header -->
# <div class="dialog_header">
# <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
# </div>
# <!-- //dialog_header -->
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <!-- form_wrap -->
# <div class="form_wrap type_md" id="authorBox">
# </div>
# <!-- //form_wrap -->
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <!-- //저자 모두보기 팝업 -->
# <!-- // LayerPopup area -->
# </div>
# <div class="prod_publish">
# <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB14984&quot;,&quot;\uD504\uB9AC\uB809&quot;);">프리렉</a>
# <span class="gap">·</span>
# <span class="date">2024년 12월 02일</span>
# </div>
# </div>
# <!-- // 저자, 출판사 정보 -->
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="percent">10%</span>
# <span class="price">
# <span class="val">22,500</span>
# <span class="unit">원 </span>
# </span>
# <span class="price_normal">
# <span class="text">정가</span>
# <s class="val">25,000원</s>
# </span>
# <span class="gap">|</span>
# <span class="point">
#                             1,250p
#                             <span class="rate">(5%)</span>
# </span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매중이 아닐떄-->
# <!--중고 장터일때-->
# <!--//가격정보 페이지-->
# <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <div class="prod_bottom">
# <!--좋아요 버튼(썸네일) 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788965404026" data-pid="S000214845678" id="searchWishItemInfo_S000214845678" name="001_001_S000214845678_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon bottom" data-cmdtcode="9788965404026" id="S000214845678_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000214845678");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# ...
#             </th:block>-->
# <!--절판,품절,일시품절 일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                 <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                     <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000216842382, , KOR);"><span class="ico_alarm"></span>
#                         <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                         <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                     </button>
#                 </th:block>
#             </th:block>-->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# <!-- 앨범 일때-->
# <!--중고 장터일때-->
# </div>
# <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
# <ul class="prod_related_list">
#
#
#
# q
#
#
#
#
#                 </ul>
# </div>
# </li>, <li class="prod_item">
# <!-- 체크박스 영역 -->
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label">
# <!--교보일때-->
# <input class="result_checkbox spec_checkbox" data-bid="9791157846825" data-cdtn-code="001" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="AI 전쟁" data-pid="S000203074995" data-prhb-age="0" id="chkSearch_S000203074995" name="001_001_S000203074995_chkSearchNm" type="checkbox"/>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <label for="chkSearch_S000203074995"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <!-- 상품 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box size_lg">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000203074995" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000203074995&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791157846825" data-kbbfn-pid="S000203074995" data-kbbfn-size="200x0" data-kbbfn-title="AI 전쟁" data-kbbfn-type="KOR"/>
# </span>
# </a>
# <div class="prod_viewer_control">
# <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000203074995&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
# </div>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <span class="badge_md badge_line_primary rep"><span class="text">MD의 선택</span></span>
# <span class="badge_md badge_line_gray"><span class="text">한정판매</span></span>
# <span class="badge_md badge_line_gray"><span class="text">이벤트</span></span>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- // 라벨 -->
# <!-- 상품명 -->
# <div class="auto_overflow_wrap prod_name_group">
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000203074995" onclick="searchResultItemClickEvent('상품 제목', &quot;S000203074995&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span id="cmdtName_S000203074995">AI 전쟁</span>
# </a>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000203074995");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# <!-- LayerPopup area -->
# <!-- 타이틀 전체보기 -->
# <div class="dialog_wrap no_title" id="popAllProdTitle">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <div class="prod_detail_title_wrap">
# <!-- prod_title_area -->
# <div class="prod_title_area">
# <!-- 상품 타이틀 -->
# <div class="prod_title_box">
# <!-- DESC : 상품 타이틀 구분 값 케이스
#                         - 일반 구분 값 : .prod_label
#                         - 관칭관제 : .prod_alias
#                         - 상품명 : .prod_title
#                     -->
# <span class="prod_label" id="gubun1"></span>
# <span class="gap gubun2">·</span>
# <span class="prod_label" id="gubun2"></span>
# <span class="gap gubun3">·</span>
# <span class="prod_label" id="gubun3"></span>
# <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# <h1>
# <span class="prod_alias" id="kwch"></span>
# <span class="prod_title" id="cmdtName"></span>
# </h1>
# <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# </div>
# <!-- //상품 타이틀 -->
# </div>
# <!-- //prod_title_area -->
# <!-- prod_desc_area -->
# <div class="prod_desc_area">
# <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc" id="subtitle_1"></span>
# <span class="gap subtitle_2"> | </span>
# <span class="prod_desc" id="subtitle_2"></span>
# <span class="gap subtitle_3"> | </span>
# <span class="prod_desc" id="subtitle_3"></span>
# </div>
# <!-- //상품 부제명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc normal" id="splmCntt"></span>
# <span class="gap bkbnShpName"> | </span>
# <span class="prod_desc normal" id="bkbnShpName"></span>
# <span class="gap setCnfgCmdtQntt"> | </span>
# <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
# </div>
# <!-- //상품 부제명 -->
# </div>
# <!-- //prod_desc_area -->
# </div>
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- //타이틀 전체보기 -->
# <!-- // LayerPopup area -->
# </div>
# </div>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# <span class="prod_desc">글로벌 인공지능 시대 한국의 미래</span>
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_info">
# <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
# <div class="auto_overflow_wrap prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1112147204&quot;,&quot;\uD558\uC815\uC6B0&quot;);">하정우</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1000525904&quot;,&quot;\uD55C\uC0C1\uAE30&quot;);">한상기</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@1112147204@\uD558\uC815\uC6B0|001@1000525904@\uD55C\uC0C1\uAE30");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# </div>
# <!--인물 페이지-->
# <!-- LayerPopup area -->
# <!-- 저자 모두보기 팝업 -->
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_header -->
# <div class="dialog_header">
# <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
# </div>
# <!-- //dialog_header -->
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <!-- form_wrap -->
# <div class="form_wrap type_md" id="authorBox">
# </div>
# <!-- //form_wrap -->
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <!-- //저자 모두보기 팝업 -->
# <!-- // LayerPopup area -->
# </div>
# <div class="prod_publish">
# <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB24692&quot;,&quot;\uD55C\uBE5B\uBE44\uC988&quot;);">한빛비즈</a>
# <span class="gap">·</span>
# <span class="date">2023년 07월 17일</span>
# </div>
# </div>
# <!-- // 저자, 출판사 정보 -->
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="percent">10%</span>
# <span class="price">
# <span class="val">17,820</span>
# <span class="unit">원 </span>
# </span>
# <span class="price_normal">
# <span class="text">정가</span>
# <s class="val">19,800원</s>
# </span>
# <span class="gap">|</span>
# <span class="point">
#                             990p
#                             <span class="rate">(5%)</span>
# </span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매중이 아닐떄-->
# <!--중고 장터일때-->
# <!--//가격정보 페이지-->
# <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <div class="prod_bottom">
# <!--좋아요 버튼(썸네일) 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9791157846825" data-pid="S000203074995" id="searchWishItemInfo_S000203074995" name="001_001_S000203074995_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon bottom" data-cmdtcode="9791157846825" id="S000203074995_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000203074995");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000203074995_CMDTCODE_VAL_BOTTOM">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
# <!--클로버리뷰-->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000203074995"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text font_size_xxs">9.7</span>
# <!--임시 조건-->
# <span class="review_desc">(22)</span>
# <!--//임시조건-->
# </span>
# <!--임시 조건-->
# <span class="gap">/</span>
# <span class="review_quotes_text font_size_xxs">도움돼요</span>
# <!--//임시조건-->
# </a>
# <!--//클로버리뷰-->
# </div>
# <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <!-- 태그 -->
# <div class="tag_wrap size_sm">
# <a class="tag" href="javascript:tagSearch('한국경제','kyobo')">#한국경제</a>
# <a class="tag" href="javascript:tagSearch('경제전망','kyobo')">#경제전망</a>
# <a class="tag" href="javascript:tagSearch('인공지능','kyobo')">#인공지능</a>
# <a class="tag" href="javascript:tagSearch('한국사회','kyobo')">#한국사회</a>
# <a class="tag" href="javascript:tagSearch('한국문화','kyobo')">#한국문화</a>
# </div>
# <!-- // 태그 -->
# <!-- 이벤트 정보 -->
# <!-- 이벤트 정보 -->
# <!--
#     (이벤트아이디@이벤트내용@이벤트구분|이벤트아이디@이벤트내용@이벤트구분)
#     이벤트 구분
#     001: 이벤트
#     002: 사은품
#     003: 경품
#     -->
# <div class="prod_gift_info"><a class="prod_gift_text" href="javascript:void(0);" onclick="goEventDetailPage(237631)">박곰희 작가 『박곰희 연금 부자 수업』 랜선 팬사인회</a><div class="tooltip_wrap type_sm">
# <div class="tooltip_inner">
# <div class="tooltip_header">
# <div class="tooltip_head_title">이벤트 안내</div>
# </div>
# <div class="tooltip_contents"><div class="tooltip_sub_title">사은품</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(237631)">박곰희 작가 『박곰희 연금 부자 수업』 랜선 팬사인회</a></li>
# </ul></div>
# <button class="btn_tooltip_close" type="button"><span class="hidden">툴팁닫기</span></button>
# </div>
# </div></div>
# <!-- // 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# </div>
# </div>
# <!-- // 상품 영역 -->
# <!-- only list type -->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!-- 배송정보 영역 -->
# <!--바로드림 전용상품이 아닐경우-->
# <div class="prod_order_state">
# <span class="badge_sm badge_pill badge_primary"><span class="text">당일배송</span></span>
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <!--<br> -->
# <span class="fw_bold">오늘(7/24, 목) </span>
# <br/>
# <span>도착</span>
# <div class="tooltip_wrap type_sm right" id="tooltip_search">
# <button class="btn_tooltip" id="btn_tooltip_search" type="button">
# <span class="ico_info"></span>
# <span class="hidden">툴팁열기</span>
# </button>
# <div class="tooltip_inner" id="tooltip_content_search">
# <div class="tooltip_header">
# <div class="tooltip_head_title">검색결과 배송일자 기준 안내</div>
# </div>
# <div class="tooltip_contents">
# <div class="tooltip_desc">
#                                     '가장 빠른 배송지' 기준
#                                     <br/>
#                                     로그인 후 상품 상세 페이지, 주문/결제 페이지에서
#                                     <br/>
# <span class="fc_spot">정확한 배송 안내</span>
#                                     를 받아보세요.
#                                 </div>
# </div>
# <button class="btn_tooltip_close" id="btn_tooltip_close_search" type="button">
# <span class="hidden">툴팁 닫기</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 리스트형 타입 버튼영역 -->
# <div class="prod_btn_wrap">
# <!--결제기능, 좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9791157846825" data-pid="S000203074995" id="searchWishItemInfo_S000203074995" name="001_001_S000203074995_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon" data-cmdtcode="9791157846825" id="S000203074995_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000203074995");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000203074995_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <div class="btn_wrap full">
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <a class="btn_sm btn_light_gray" href="javascript:;" onclick='searchResultCartClickEvent(false, "S000203074995");'><span class="text">장바구니</span></a>
# <a class="btn_sm btn_primary" href="javascript:;" onclick='searchResultDirectOrderClickEvent("S000203074995");'><span class="text">바로구매</span></a>
# <!--품절 상품일때-->
# <!--출시예정 상품일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '004'">
#                 <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000203074995, SGK, KOR);"><span class="ico_alarm"></span><span class="text">출시알림</span></button>
#             </th:block>-->
# <!--절판,품절,일시품절 일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                 <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                     <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000203074995, , KOR);"><span class="ico_alarm"></span>
#                         <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                         <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                     </button>
#                 </th:block>
#             </th:block>-->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# <!-- 앨범 일때-->
# <!--중고 장터일때-->
# </div>
# <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
# <ul class="prod_related_list">
# <li class="btn_item">
# <a class="btn_xxs btn_pill btn_line_gray" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000005314732" onclick="searchResultItemClickEvent('eBook', &quot;S000203074995&quot;);">
# <span class="text">eBook</span><span class="ico_arw"></span>
# </a>
# </li>
#
# q
#
#
#
#
#                 </ul>
# </div>
# </li>]

# %%
one = prod_item[0]
one
# Out:
# <li class="prod_item">
# <!-- 체크박스 영역 -->
# <!-- 체크박스 영역 -->
# <span class="form_chk no_label">
# <!--교보일때-->
# <input class="result_checkbox spec_checkbox" data-bid="9788955685329" data-cdtn-code="008" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="인공지능입문" data-pid="S000217120455" data-prhb-age="0" id="chkSearch_S000217120455" name="001_001_S000217120455_chkSearchNm" type="checkbox"/>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <label for="chkSearch_S000217120455"><span class="hidden">상품선택</span></label>
# </span>
# <!-- // 체크박스 영역 -->
# <!-- 상품 영역 -->
# <div class="prod_area horizontal">
# <div class="prod_thumb_box size_lg">
# <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000217120455&quot;);">
# <span class="img_box">
# <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9788955685329" data-kbbfn-pid="S000217120455" data-kbbfn-size="200x0" data-kbbfn-title="인공지능입문" data-kbbfn-type="KOR"/>
# </span>
# </a>
# <div class="prod_viewer_control">
# <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000217120455&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
# </div>
# </div>
# <div class="prod_info_box">
# <!-- 라벨 -->
# <!-- 라벨 페이지 -->
# <div class="prod_badge">
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# </div>
# <!-- // 라벨 -->
# <!-- 상품명 -->
# <div class="auto_overflow_wrap prod_name_group">
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217120455&quot;);">
# <span class="prod_category">[국내도서]</span>
# <span class="prod_label" id="gubun3_S000217120455">예약판매</span>
# <span id="cmdtName_S000217120455">인공지능입문</span>
# </a>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000217120455");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# <!-- LayerPopup area -->
# <!-- 타이틀 전체보기 -->
# <div class="dialog_wrap no_title" id="popAllProdTitle">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <div class="prod_detail_title_wrap">
# <!-- prod_title_area -->
# <div class="prod_title_area">
# <!-- 상품 타이틀 -->
# <div class="prod_title_box">
# <!-- DESC : 상품 타이틀 구분 값 케이스
#                         - 일반 구분 값 : .prod_label
#                         - 관칭관제 : .prod_alias
#                         - 상품명 : .prod_title
#                     -->
# <span class="prod_label" id="gubun1"></span>
# <span class="gap gubun2">·</span>
# <span class="prod_label" id="gubun2"></span>
# <span class="gap gubun3">·</span>
# <span class="prod_label" id="gubun3"></span>
# <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# <h1>
# <span class="prod_alias" id="kwch"></span>
# <span class="prod_title" id="cmdtName"></span>
# </h1>
# <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
# </div>
# <!-- //상품 타이틀 -->
# </div>
# <!-- //prod_title_area -->
# <!-- prod_desc_area -->
# <div class="prod_desc_area">
# <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc" id="subtitle_1"></span>
# <span class="gap subtitle_2"> | </span>
# <span class="prod_desc" id="subtitle_2"></span>
# <span class="gap subtitle_3"> | </span>
# <span class="prod_desc" id="subtitle_3"></span>
# </div>
# <!-- //상품 부제명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_box">
# <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                         - 부제명 : 추가 클래스 X
#                         - 일반 부가 정보 : .normal 클래스 추가
#                     -->
# <span class="prod_desc normal" id="splmCntt"></span>
# <span class="gap bkbnShpName"> | </span>
# <span class="prod_desc normal" id="bkbnShpName"></span>
# <span class="gap setCnfgCmdtQntt"> | </span>
# <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
# </div>
# <!-- //상품 부제명 -->
# </div>
# <!-- //prod_desc_area -->
# </div>
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- //타이틀 전체보기 -->
# <!-- // LayerPopup area -->
# </div>
# </div>
# <!-- // 상품명 -->
# <!-- 상품 부제명 -->
# <div class="prod_desc_info">
# </div>
# <!-- // 상품 부제명 -->
# <!-- 저자, 출판사 정보 -->
# <div class="prod_author_info">
# <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
# <div class="auto_overflow_wrap prod_author_group">
# <!--인물 페이지-->
# <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
# <div class="auto_overflow_contents">
# <div class="auto_overflow_inner">
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# <span class="gap"> | </span>
# <!--인물 페이지-->
# <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
# <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
# <!--인물역할코드 페이지-->
# <!--인물역할코드-->
# <span class="type">저자(글)</span>
# <span class="count">외</span>
# </div>
# </div>
# <div class="auto_overflow_footer">
# <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@@\uC190\uCC3D\uD638|001@@\uC774\uC740\uC560");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
# </div>
# <!--인물 페이지-->
# <!-- LayerPopup area -->
# <!-- 저자 모두보기 팝업 -->
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_header -->
# <div class="dialog_header">
# <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
# </div>
# <!-- //dialog_header -->
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <!-- form_wrap -->
# <div class="form_wrap type_md" id="authorBox">
# </div>
# <!-- //form_wrap -->
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- 수정 211207 div.dialog_author 클래스 추가 -->
# <!-- //저자 모두보기 팝업 -->
# <!-- // LayerPopup area -->
# </div>
# <div class="prod_publish">
# <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</a>
# <span class="gap">·</span>
# <span class="date">2025년 07월 31일</span>
# </div>
# </div>
# <!-- // 저자, 출판사 정보 -->
# <!--가격정보 페이지-->
# <!-- 가격정보 페이지 -->
# <!--판매중일떄-->
# <!--교보일때-->
# <!--종이책, 컬쳐(유료), GIFT일때-->
# <div class="prod_price">
# <span class="percent">10%</span>
# <span class="price">
# <span class="val">12,600</span>
# <span class="unit">원 </span>
# </span>
# <span class="price_normal">
# <span class="text">정가</span>
# <s class="val">14,000원</s>
# </span>
# <span class="gap">|</span>
# <span class="point">
#                             700p
#                             <span class="rate">(5%)</span>
# </span>
# </div>
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--판매중이 아닐떄-->
# <!--중고 장터일때-->
# <!--//가격정보 페이지-->
# <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <div class="prod_bottom">
# <!--좋아요 버튼(썸네일) 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon bottom" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217120455_CMDTCODE_VAL_BOTTOM">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
# <!--클로버리뷰-->
# <!-- 클로버 리뷰 페이지 -->
# <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage(
#        "KOR",
#        "S000217120455"
#         );'>
# <span class="review_klover_box">
# <span class="review_klover_text font_size_xxs">0.0</span>
# <!--임시 조건-->
# <span class="review_desc">(0)</span>
# <!--//임시조건-->
# </span>
# <!--임시 조건-->
# <!--//임시조건-->
# </a>
# <!--//클로버리뷰-->
# </div>
# <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
# <!-- 태그 -->
# <div class="tag_wrap size_sm">
# </div>
# <!-- // 태그 -->
# <!-- 이벤트 정보 -->
# <!-- // 이벤트 정보 -->
# </div>
# </div>
# <!-- // 상품 영역 -->
# <!-- only list type -->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
# <!-- 배송정보 영역 -->
# <!--바로드림 전용상품이 아닐경우-->
# <div class="prod_order_state">
# <div class="order_state_desc">
# <!--<span>지금 주문하면</span> -->
# <!--<br> -->
# <span class="fw_bold">7/31(목)</span>
# <br/>
# <span>출고예정</span>
# <div class="tooltip_wrap type_sm right" id="tooltip_search">
# <button class="btn_tooltip" id="btn_tooltip_search" type="button">
# <span class="ico_info"></span>
# <span class="hidden">툴팁열기</span>
# </button>
# <div class="tooltip_inner" id="tooltip_content_search">
# <div class="tooltip_header">
# <div class="tooltip_head_title">검색결과 배송일자 기준 안내</div>
# </div>
# <div class="tooltip_contents">
# <div class="tooltip_desc">
#                                     '가장 빠른 배송지' 기준
#                                     <br/>
#                                     로그인 후 상품 상세 페이지, 주문/결제 페이지에서
#                                     <br/>
# <span class="fc_spot">정확한 배송 안내</span>
#                                     를 받아보세요.
#                                 </div>
# </div>
# <button class="btn_tooltip_close" id="btn_tooltip_close_search" type="button">
# <span class="hidden">툴팁 닫기</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <!-- // 배송정보 영역 -->
# <!--</th:block>-->
# <!-- 리스트형 타입 버튼영역 -->
# <div class="prod_btn_wrap">
# <!--결제기능, 좋아요 버튼 정책 레이아웃-->
# <!-- 좋아요 버튼 정책 레이아웃-->
# <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
# <!--교보일때-->
# <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
# <button class="btn_wish_icon" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
# <span class="val" id="S000217120455_CMDTCODE_VAL">0</span>
# </button>
# <!--ebook/sam일때-->
# <!--핫트랙스일때-->
# <!--중고 장터일때-->
# <!--캐스팅일때-->
# <!--결제기능 버튼 정책 레이아웃-->
# <div class="btn_wrap full">
# <!--교보일때-->
# <!--판매중/예약중 일떄-->
# <!--or-->
# <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
# <a class="btn_sm btn_light_gray" href="javascript:;" onclick='searchResultCartClickEvent(false, "S000217120455");'><span class="text">장바구니</span></a>
# <a class="btn_sm btn_primary" href="javascript:;" onclick='searchResultDirectOrderClickEvent("S000217120455");'><span class="text">바로구매</span></a>
# <!--품절 상품일때-->
# <!--출시예정 상품일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '004'">
#                 <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000217120455, SGK, KOR);"><span class="ico_alarm"></span><span class="text">출시알림</span></button>
#             </th:block>-->
# <!--절판,품절,일시품절 일때-->
# <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                 <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                     <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000217120455, , KOR);"><span class="ico_alarm"></span>
#                         <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                         <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                     </button>
#                 </th:block>
#             </th:block>-->
# <!--ebook/sam 일때-->
# <!--핫트랙스일때-->
# <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
# <!-- 앨범 일때-->
# <!--중고 장터일때-->
# </div>
# <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
# <ul class="prod_related_list">
#
#
#
# q
#
#
#
#
#                 </ul>
# </div>
# </li>

# %%
info_box = one.select("#shopData_list > ul > li:nth-child(1) > div.prod_area.horizontal > div.prod_info_box")
info_box
# Out:
# [<div class="prod_info_box">
#  <!-- 라벨 -->
#  <!-- 라벨 페이지 -->
#  <div class="prod_badge">
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  </div>
#  <!-- // 라벨 -->
#  <!-- 상품명 -->
#  <div class="auto_overflow_wrap prod_name_group">
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000217120455" onclick="searchResultItemClickEvent('상품 제목', &quot;S000217120455&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span class="prod_label" id="gubun3_S000217120455">예약판매</span>
#  <span id="cmdtName_S000217120455">인공지능입문</span>
#  </a>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000217120455");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  <!-- LayerPopup area -->
#  <!-- 타이틀 전체보기 -->
#  <div class="dialog_wrap no_title" id="popAllProdTitle">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <div class="prod_detail_title_wrap">
#  <!-- prod_title_area -->
#  <div class="prod_title_area">
#  <!-- 상품 타이틀 -->
#  <div class="prod_title_box">
#  <!-- DESC : 상품 타이틀 구분 값 케이스
#                          - 일반 구분 값 : .prod_label
#                          - 관칭관제 : .prod_alias
#                          - 상품명 : .prod_title
#                      -->
#  <span class="prod_label" id="gubun1"></span>
#  <span class="gap gubun2">·</span>
#  <span class="prod_label" id="gubun2"></span>
#  <span class="gap gubun3">·</span>
#  <span class="prod_label" id="gubun3"></span>
#  <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  <h1>
#  <span class="prod_alias" id="kwch"></span>
#  <span class="prod_title" id="cmdtName"></span>
#  </h1>
#  <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  </div>
#  <!-- //상품 타이틀 -->
#  </div>
#  <!-- //prod_title_area -->
#  <!-- prod_desc_area -->
#  <div class="prod_desc_area">
#  <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc" id="subtitle_1"></span>
#  <span class="gap subtitle_2"> | </span>
#  <span class="prod_desc" id="subtitle_2"></span>
#  <span class="gap subtitle_3"> | </span>
#  <span class="prod_desc" id="subtitle_3"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc normal" id="splmCntt"></span>
#  <span class="gap bkbnShpName"> | </span>
#  <span class="prod_desc normal" id="bkbnShpName"></span>
#  <span class="gap setCnfgCmdtQntt"> | </span>
#  <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  </div>
#  <!-- //prod_desc_area -->
#  </div>
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- //타이틀 전체보기 -->
#  <!-- // LayerPopup area -->
#  </div>
#  </div>
#  <!-- // 상품명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_info">
#  </div>
#  <!-- // 상품 부제명 -->
#  <!-- 저자, 출판사 정보 -->
#  <div class="prod_author_info">
#  <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
#  <div class="auto_overflow_wrap prod_author_group">
#  <!--인물 페이지-->
#  <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC190\uCC3D\uD638&quot;);">손창호</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">저자(글)</span>
#  <span class="gap"> | </span>
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;null&quot;,&quot;\uC774\uC740\uC560&quot;);">이은애</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">저자(글)</span>
#  <span class="count">외</span>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@@\uC190\uCC3D\uD638|001@@\uC774\uC740\uC560");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  </div>
#  <!--인물 페이지-->
#  <!-- LayerPopup area -->
#  <!-- 저자 모두보기 팝업 -->
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_header -->
#  <div class="dialog_header">
#  <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
#  </div>
#  <!-- //dialog_header -->
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <!-- form_wrap -->
#  <div class="form_wrap type_md" id="authorBox">
#  </div>
#  <!-- //form_wrap -->
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <!-- //저자 모두보기 팝업 -->
#  <!-- // LayerPopup area -->
#  </div>
#  <div class="prod_publish">
#  <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB04390&quot;,&quot;\uC591\uC11C\uAC01&quot;);">양서각</a>
#  <span class="gap">·</span>
#  <span class="date">2025년 07월 31일</span>
#  </div>
#  </div>
#  <!-- // 저자, 출판사 정보 -->
#  <!--가격정보 페이지-->
#  <!-- 가격정보 페이지 -->
#  <!--판매중일떄-->
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">12,600</span>
#  <span class="unit">원 </span>
#  </span>
#  <span class="price_normal">
#  <span class="text">정가</span>
#  <s class="val">14,000원</s>
#  </span>
#  <span class="gap">|</span>
#  <span class="point">
#                              700p
#                              <span class="rate">(5%)</span>
#  </span>
#  </div>
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  <!--판매중이 아닐떄-->
#  <!--중고 장터일때-->
#  <!--//가격정보 페이지-->
#  <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <div class="prod_bottom">
#  <!--좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9788955685329" data-pid="S000217120455" id="searchWishItemInfo_S000217120455" name="001_001_S000217120455_searchWishItemNm" type="hidden"/>
#  <button class="btn_wish_icon bottom" data-cmdtcode="9788955685329" id="S000217120455_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000217120455");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000217120455_CMDTCODE_VAL_BOTTOM">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!--클로버리뷰-->
#  <!-- 클로버 리뷰 페이지 -->
#  <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage(
#         "KOR",
#         "S000217120455"
#          );'>
#  <span class="review_klover_box">
#  <span class="review_klover_text font_size_xxs">0.0</span>
#  <!--임시 조건-->
#  <span class="review_desc">(0)</span>
#  <!--//임시조건-->
#  </span>
#  <!--임시 조건-->
#  <!--//임시조건-->
#  </a>
#  <!--//클로버리뷰-->
#  </div>
#  <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <!-- 태그 -->
#  <div class="tag_wrap size_sm">
#  </div>
#  <!-- // 태그 -->
#  <!-- 이벤트 정보 -->
#  <!-- // 이벤트 정보 -->
#  </div>]

# %%
title = info_box[0].select_one("div.auto_overflow_wrap.prod_name_group > div.auto_overflow_contents").text
title.replace("\n", " ").strip()
# Out:
# '[국내도서] 예약판매 인공지능입문'
